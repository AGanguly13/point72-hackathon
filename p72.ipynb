# %%
import requests
from google.transit import gtfs_realtime_pb2
import pandas as pd

def fetch_and_decode_gtfs_realtime_data(url):
    # Make a request to the GTFS Realtime feed URL
    response = requests.get(url, headers={"x-api-key": "YOUR_API_KEY_HERE"})
    # Initialize a FeedMessage, which is the top-level object in the protobuf definition
    feed = gtfs_realtime_pb2.FeedMessage()
    # Parse the response content into the feed
    feed.ParseFromString(response.content)
    return feed

# Specify your GTFS Realtime API endpoint
url = "https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-bdfm"

# Call the function to fetch and decode the data
decoded_data = fetch_and_decode_gtfs_realtime_data(url)

# Example of accessing data: print all trip updates
for entity in decoded_data.entity:
    if entity.HasField('trip_update'):
        print(entity.trip_update)
# Out:
# trip {
#   trip_id: "120250_B..N46R"
#   start_time: "20:02:30"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2002+ BBC/145"
#     is_assigned: true
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179479
#   }
#   departure {
#     time: 1714179479
#   }
#   stop_id: "A19N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179545
#   }
#   departure {
#     time: 1714179545
#   }
#   stop_id: "A18N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179605
#   }
#   departure {
#     time: 1714179605
#   }
#   stop_id: "A17N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179695
#   }
#   departure {
#     time: 1714179695
#   }
#   stop_id: "A16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179785
#   }
#   departure {
#     time: 1714179785
#   }
#   stop_id: "A15N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179875
#   }
#   departure {
#     time: 1714179875
#   }
#   stop_id: "A14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179995
#   }
#   departure {
#     time: 1714179995
#   }
#   stop_id: "D13N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "CM"
#     actual_track: "CM"
#   }
# }
#
# trip {
#   trip_id: "119500_B..S46R"
#   start_time: "19:55:00"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 1955 145/BBC"
#     is_assigned: true
#     direction: SOUTH
#   }
# }
#
# trip {
#   trip_id: "120500_B..S46R"
#   start_time: "20:05:00"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2005 145/BBC"
#     is_assigned: true
#     direction: SOUTH
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179634
#   }
#   departure {
#     time: 1714179634
#   }
#   stop_id: "D35S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179979
#   }
#   departure {
#     time: 1714179979
#   }
#   stop_id: "D39S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180144
#   }
#   departure {
#     time: 1714180144
#   }
#   stop_id: "D40S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
#
# trip {
#   trip_id: "121250_B..N46R"
#   start_time: "20:12:30"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2012+ BBC/145"
#     is_assigned: true
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179473
#   }
#   departure {
#     time: 1714179473
#   }
#   stop_id: "D14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179545
#   }
#   departure {
#     time: 1714179545
#   }
#   stop_id: "A24N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179635
#   }
#   departure {
#     time: 1714179635
#   }
#   stop_id: "A22N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179725
#   }
#   departure {
#     time: 1714179725
#   }
#   stop_id: "A21N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179815
#   }
#   departure {
#     time: 1714179815
#   }
#   stop_id: "A20N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179905
#   }
#   departure {
#     time: 1714179905
#   }
#   stop_id: "A19N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179995
#   }
#   departure {
#     time: 1714179995
#   }
#   stop_id: "A18N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180055
#   }
#   departure {
#     time: 1714180055
#   }
#   stop_id: "A17N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180145
#   }
#   departure {
#     time: 1714180145
#   }
#   stop_id: "A16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180235
#   }
#   departure {
#     time: 1714180235
#   }
#   stop_id: "A15N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180325
#   }
#   departure {
#     time: 1714180325
#   }
#   stop_id: "A14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180445
#   }
#   departure {
#     time: 1714180445
#   }
#   stop_id: "D13N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "CM"
#     actual_track: "CM"
#   }
# }
#
# trip {
#   trip_id: "121500_B..S46R"
#   start_time: "20:15:00"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2015 145/BBC"
#     is_assigned: true
#     direction: SOUTH
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179479
#   }
#   departure {
#     time: 1714179479
#   }
#   stop_id: "D24S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179545
#   }
#   departure {
#     time: 1714179545
#   }
#   stop_id: "D25S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179815
#   }
#   departure {
#     time: 1714179815
#   }
#   stop_id: "D26S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179935
#   }
#   departure {
#     time: 1714179935
#   }
#   stop_id: "D28S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180085
#   }
#   departure {
#     time: 1714180085
#   }
#   stop_id: "D31S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180385
#   }
#   departure {
#     time: 1714180385
#   }
#   stop_id: "D35S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180730
#   }
#   departure {
#     time: 1714180730
#   }
#   stop_id: "D39S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180895
#   }
#   departure {
#     time: 1714180895
#   }
#   stop_id: "D40S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
#
# trip {
#   trip_id: "122250_B..N46R"
#   start_time: "20:22:32"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2022+ BBC/145"
#     is_assigned: true
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179481
#   }
#   departure {
#     time: 1714179481
#   }
#   stop_id: "D21N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179588
#   }
#   departure {
#     time: 1714179588
#   }
#   stop_id: "D20N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179768
#   }
#   departure {
#     time: 1714179768
#   }
#   stop_id: "D17N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179858
#   }
#   departure {
#     time: 1714179858
#   }
#   stop_id: "D16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179948
#   }
#   departure {
#     time: 1714179948
#   }
#   stop_id: "D15N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180038
#   }
#   departure {
#     time: 1714180038
#   }
#   stop_id: "D14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180158
#   }
#   departure {
#     time: 1714180158
#   }
#   stop_id: "A24N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180248
#   }
#   departure {
#     time: 1714180248
#   }
#   stop_id: "A22N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180338
#   }
#   departure {
#     time: 1714180338
#   }
#   stop_id: "A21N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180428
#   }
#   departure {
#     time: 1714180428
#   }
#   stop_id: "A20N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180518
#   }
#   departure {
#     time: 1714180518
#   }
#   stop_id: "A19N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180608
#   }
#   departure {
#     time: 1714180608
#   }
#   stop_id: "A18N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180668
#   }
#   departure {
#     time: 1714180668
#   }
#   stop_id: "A17N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180758
#   }
#   departure {
#     time: 1714180758
#   }
#   stop_id: "A16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180848
#   }
#   departure {
#     time: 1714180848
#   }
#   stop_id: "A15N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180938
#   }
#   departure {
#     time: 1714180938
#   }
#   stop_id: "A14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181058
#   }
#   departure {
#     time: 1714181058
#   }
#   stop_id: "D13N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "CM"
#     actual_track: "CM"
#   }
# }
#
# trip {
#   trip_id: "122500_B..S46R"
#   start_time: "20:25:00"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2025 145/BBC"
#     is_assigned: true
#     direction: SOUTH
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179478
#   }
#   departure {
#     time: 1714179478
#   }
#   stop_id: "D22S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179880
#   }
#   departure {
#     time: 1714179880
#   }
#   stop_id: "R30S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180000
#   }
#   departure {
#     time: 1714180000
#   }
#   stop_id: "D24S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180120
#   }
#   departure {
#     time: 1714180120
#   }
#   stop_id: "D25S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180390
#   }
#   departure {
#     time: 1714180390
#   }
#   stop_id: "D26S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180510
#   }
#   departure {
#     time: 1714180510
#   }
#   stop_id: "D28S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180660
#   }
#   departure {
#     time: 1714180660
#   }
#   stop_id: "D31S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180960
#   }
#   departure {
#     time: 1714180960
#   }
#   stop_id: "D35S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181305
#   }
#   departure {
#     time: 1714181305
#   }
#   stop_id: "D39S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181470
#   }
#   departure {
#     time: 1714181470
#   }
#   stop_id: "D40S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
#
# trip {
#   trip_id: "123500_B..S46R"
#   start_time: "20:34:00"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2035 145/BBC"
#     is_assigned: true
#     direction: SOUTH
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179479
#   }
#   departure {
#     time: 1714179479
#   }
#   stop_id: "D16S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179545
#   }
#   departure {
#     time: 1714179545
#   }
#   stop_id: "D17S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179725
#   }
#   departure {
#     time: 1714179725
#   }
#   stop_id: "D20S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179845
#   }
#   departure {
#     time: 1714179845
#   }
#   stop_id: "D21S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179965
#   }
#   departure {
#     time: 1714179965
#   }
#   stop_id: "D22S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180475
#   }
#   departure {
#     time: 1714180475
#   }
#   stop_id: "R30S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180565
#   }
#   departure {
#     time: 1714180565
#   }
#   stop_id: "D24S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180715
#   }
#   departure {
#     time: 1714180715
#   }
#   stop_id: "D25S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180955
#   }
#   departure {
#     time: 1714180955
#   }
#   stop_id: "D26S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181075
#   }
#   departure {
#     time: 1714181075
#   }
#   stop_id: "D28S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181225
#   }
#   departure {
#     time: 1714181225
#   }
#   stop_id: "D31S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181525
#   }
#   departure {
#     time: 1714181525
#   }
#   stop_id: "D35S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181870
#   }
#   departure {
#     time: 1714181870
#   }
#   stop_id: "D39S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182035
#   }
#   departure {
#     time: 1714182035
#   }
#   stop_id: "D40S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
#
# trip {
#   trip_id: "123250_B..N46R"
#   start_time: "20:32:30"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2032+ BBC/145"
#     is_assigned: true
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179479
#   }
#   departure {
#     time: 1714179479
#   }
#   stop_id: "R30N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179990
#   }
#   departure {
#     time: 1714179990
#   }
#   stop_id: "D22N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180110
#   }
#   departure {
#     time: 1714180110
#   }
#   stop_id: "D21N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180230
#   }
#   departure {
#     time: 1714180230
#   }
#   stop_id: "D20N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180410
#   }
#   departure {
#     time: 1714180410
#   }
#   stop_id: "D17N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180500
#   }
#   departure {
#     time: 1714180500
#   }
#   stop_id: "D16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180590
#   }
#   departure {
#     time: 1714180590
#   }
#   stop_id: "D15N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180680
#   }
#   departure {
#     time: 1714180680
#   }
#   stop_id: "D14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180800
#   }
#   departure {
#     time: 1714180800
#   }
#   stop_id: "A24N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180890
#   }
#   departure {
#     time: 1714180890
#   }
#   stop_id: "A22N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180980
#   }
#   departure {
#     time: 1714180980
#   }
#   stop_id: "A21N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181070
#   }
#   departure {
#     time: 1714181070
#   }
#   stop_id: "A20N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181160
#   }
#   departure {
#     time: 1714181160
#   }
#   stop_id: "A19N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181250
#   }
#   departure {
#     time: 1714181250
#   }
#   stop_id: "A18N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181310
#   }
#   departure {
#     time: 1714181310
#   }
#   stop_id: "A17N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181400
#   }
#   departure {
#     time: 1714181400
#   }
#   stop_id: "A16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181490
#   }
#   departure {
#     time: 1714181490
#   }
#   stop_id: "A15N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181580
#   }
#   departure {
#     time: 1714181580
#   }
#   stop_id: "A14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181700
#   }
#   departure {
#     time: 1714181700
#   }
#   stop_id: "D13N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "CM"
#     actual_track: "CM"
#   }
# }
#
# trip {
#   trip_id: "124250_B..N46R"
#   start_time: "20:43:07"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2042+ BBC/145"
#     is_assigned: true
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179479
#   }
#   departure {
#     time: 1714179479
#   }
#   stop_id: "D26N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179691
#   }
#   departure {
#     time: 1714179691
#   }
#   stop_id: "D25N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179841
#   }
#   departure {
#     time: 1714179841
#   }
#   stop_id: "D24N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180081
#   }
#   departure {
#     time: 1714180081
#   }
#   stop_id: "R30N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180711
#   }
#   departure {
#     time: 1714180711
#   }
#   stop_id: "D22N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180831
#   }
#   departure {
#     time: 1714180831
#   }
#   stop_id: "D21N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180951
#   }
#   departure {
#     time: 1714180951
#   }
#   stop_id: "D20N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181131
#   }
#   departure {
#     time: 1714181131
#   }
#   stop_id: "D17N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181221
#   }
#   departure {
#     time: 1714181221
#   }
#   stop_id: "D16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181311
#   }
#   departure {
#     time: 1714181311
#   }
#   stop_id: "D15N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181401
#   }
#   departure {
#     time: 1714181401
#   }
#   stop_id: "D14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181521
#   }
#   departure {
#     time: 1714181521
#   }
#   stop_id: "A24N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181611
#   }
#   departure {
#     time: 1714181611
#   }
#   stop_id: "A22N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181701
#   }
#   departure {
#     time: 1714181701
#   }
#   stop_id: "A21N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181791
#   }
#   departure {
#     time: 1714181791
#   }
#   stop_id: "A20N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181881
#   }
#   departure {
#     time: 1714181881
#   }
#   stop_id: "A19N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181971
#   }
#   departure {
#     time: 1714181971
#   }
#   stop_id: "A18N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182031
#   }
#   departure {
#     time: 1714182031
#   }
#   stop_id: "A17N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182121
#   }
#   departure {
#     time: 1714182121
#   }
#   stop_id: "A16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182211
#   }
#   departure {
#     time: 1714182211
#   }
#   stop_id: "A15N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182301
#   }
#   departure {
#     time: 1714182301
#   }
#   stop_id: "A14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182421
#   }
#   departure {
#     time: 1714182421
#   }
#   stop_id: "D13N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "CM"
#     actual_track: "CM"
#   }
# }
#
# trip {
#   trip_id: "124500_B..S46R"
#   start_time: "20:45:00"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2045 145/BBC"
#     is_assigned: true
#     direction: SOUTH
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179478
#   }
#   departure {
#     time: 1714179478
#   }
#   stop_id: "A21S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179545
#   }
#   departure {
#     time: 1714179545
#   }
#   stop_id: "A22S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179635
#   }
#   departure {
#     time: 1714179635
#   }
#   stop_id: "A24S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179755
#   }
#   departure {
#     time: 1714179755
#   }
#   stop_id: "D14S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179845
#   }
#   departure {
#     time: 1714179845
#   }
#   stop_id: "D15S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179935
#   }
#   departure {
#     time: 1714179935
#   }
#   stop_id: "D16S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180025
#   }
#   departure {
#     time: 1714180025
#   }
#   stop_id: "D17S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180205
#   }
#   departure {
#     time: 1714180205
#   }
#   stop_id: "D20S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180325
#   }
#   departure {
#     time: 1714180325
#   }
#   stop_id: "D21S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180445
#   }
#   departure {
#     time: 1714180445
#   }
#   stop_id: "D22S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180925
#   }
#   departure {
#     time: 1714180925
#   }
#   stop_id: "R30S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181015
#   }
#   departure {
#     time: 1714181015
#   }
#   stop_id: "D24S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181165
#   }
#   departure {
#     time: 1714181165
#   }
#   stop_id: "D25S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181405
#   }
#   departure {
#     time: 1714181405
#   }
#   stop_id: "D26S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181525
#   }
#   departure {
#     time: 1714181525
#   }
#   stop_id: "D28S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181675
#   }
#   departure {
#     time: 1714181675
#   }
#   stop_id: "D31S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181975
#   }
#   departure {
#     time: 1714181975
#   }
#   stop_id: "D35S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182320
#   }
#   departure {
#     time: 1714182320
#   }
#   stop_id: "D39S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182485
#   }
#   departure {
#     time: 1714182485
#   }
#   stop_id: "D40S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
#
# trip {
#   trip_id: "125350_B..N46R"
#   start_time: "20:53:30"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2053+ BBC/145"
#     is_assigned: true
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179479
#   }
#   departure {
#     time: 1714179479
#   }
#   stop_id: "D39N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179629
#   }
#   departure {
#     time: 1714179629
#   }
#   stop_id: "D35N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179899
#   }
#   departure {
#     time: 1714179899
#   }
#   stop_id: "D31N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180049
#   }
#   departure {
#     time: 1714180049
#   }
#   stop_id: "D28N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180169
#   }
#   departure {
#     time: 1714180169
#   }
#   stop_id: "D26N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180379
#   }
#   departure {
#     time: 1714180379
#   }
#   stop_id: "D25N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180499
#   }
#   departure {
#     time: 1714180499
#   }
#   stop_id: "D24N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180739
#   }
#   departure {
#     time: 1714180739
#   }
#   stop_id: "R30N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A4"
#     actual_track: "A4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181369
#   }
#   departure {
#     time: 1714181369
#   }
#   stop_id: "D22N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181489
#   }
#   departure {
#     time: 1714181489
#   }
#   stop_id: "D21N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181609
#   }
#   departure {
#     time: 1714181609
#   }
#   stop_id: "D20N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181789
#   }
#   departure {
#     time: 1714181789
#   }
#   stop_id: "D17N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181879
#   }
#   departure {
#     time: 1714181879
#   }
#   stop_id: "D16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181969
#   }
#   departure {
#     time: 1714181969
#   }
#   stop_id: "D15N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182059
#   }
#   departure {
#     time: 1714182059
#   }
#   stop_id: "D14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B4"
#     actual_track: "B4"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182179
#   }
#   departure {
#     time: 1714182179
#   }
#   stop_id: "A24N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182269
#   }
#   departure {
#     time: 1714182269
#   }
#   stop_id: "A22N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182359
#   }
#   departure {
#     time: 1714182359
#   }
#   stop_id: "A21N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182449
#   }
#   departure {
#     time: 1714182449
#   }
#   stop_id: "A20N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182539
#   }
#   departure {
#     time: 1714182539
#   }
#   stop_id: "A19N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182629
#   }
#   departure {
#     time: 1714182629
#   }
#   stop_id: "A18N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182689
#   }
#   departure {
#     time: 1714182689
#   }
#   stop_id: "A17N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182779
#   }
#   departure {
#     time: 1714182779
#   }
#   stop_id: "A16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182869
#   }
#   departure {
#     time: 1714182869
#   }
#   stop_id: "A15N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182959
#   }
#   departure {
#     time: 1714182959
#   }
#   stop_id: "A14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A2"
#     actual_track: "A2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183079
#   }
#   departure {
#     time: 1714183079
#   }
#   stop_id: "D13N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "CM"
#     actual_track: "CM"
#   }
# }
#
# trip {
#   trip_id: "126500_B..S46R"
#   start_time: "21:05:00"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2105 145/BBC"
#     direction: SOUTH
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179900
#   }
#   departure {
#     time: 1714179900
#   }
#   stop_id: "D13S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "CM"
#     actual_track: "CM"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180050
#   }
#   departure {
#     time: 1714180050
#   }
#   stop_id: "A14S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180140
#   }
#   departure {
#     time: 1714180140
#   }
#   stop_id: "A15S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180230
#   }
#   departure {
#     time: 1714180230
#   }
#   stop_id: "A16S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180320
#   }
#   departure {
#     time: 1714180320
#   }
#   stop_id: "A17S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180380
#   }
#   departure {
#     time: 1714180380
#   }
#   stop_id: "A18S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180470
#   }
#   departure {
#     time: 1714180470
#   }
#   stop_id: "A19S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180560
#   }
#   departure {
#     time: 1714180560
#   }
#   stop_id: "A20S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180650
#   }
#   departure {
#     time: 1714180650
#   }
#   stop_id: "A21S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180740
#   }
#   departure {
#     time: 1714180740
#   }
#   stop_id: "A22S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180830
#   }
#   departure {
#     time: 1714180830
#   }
#   stop_id: "A24S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180950
#   }
#   departure {
#     time: 1714180950
#   }
#   stop_id: "D14S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181040
#   }
#   departure {
#     time: 1714181040
#   }
#   stop_id: "D15S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181130
#   }
#   departure {
#     time: 1714181130
#   }
#   stop_id: "D16S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181220
#   }
#   departure {
#     time: 1714181220
#   }
#   stop_id: "D17S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181400
#   }
#   departure {
#     time: 1714181400
#   }
#   stop_id: "D20S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181520
#   }
#   departure {
#     time: 1714181520
#   }
#   stop_id: "D21S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181640
#   }
#   departure {
#     time: 1714181640
#   }
#   stop_id: "D22S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182120
#   }
#   departure {
#     time: 1714182120
#   }
#   stop_id: "R30S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182210
#   }
#   departure {
#     time: 1714182210
#   }
#   stop_id: "D24S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182360
#   }
#   departure {
#     time: 1714182360
#   }
#   stop_id: "D25S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182600
#   }
#   departure {
#     time: 1714182600
#   }
#   stop_id: "D26S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182720
#   }
#   departure {
#     time: 1714182720
#   }
#   stop_id: "D28S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182870
#   }
#   departure {
#     time: 1714182870
#   }
#   stop_id: "D31S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183170
#   }
#   departure {
#     time: 1714183170
#   }
#   stop_id: "D35S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183515
#   }
#   departure {
#     time: 1714183515
#   }
#   stop_id: "D39S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183680
#   }
#   departure {
#     time: 1714183680
#   }
#   stop_id: "D40S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
#
# trip {
#   trip_id: "125500_B..S46R"
#   start_time: "20:55:00"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2055 145/BBC"
#     is_assigned: true
#     direction: SOUTH
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179479
#   }
#   departure {
#     time: 1714179479
#   }
#   stop_id: "A14S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179545
#   }
#   departure {
#     time: 1714179545
#   }
#   stop_id: "A15S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179635
#   }
#   departure {
#     time: 1714179635
#   }
#   stop_id: "A16S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179725
#   }
#   departure {
#     time: 1714179725
#   }
#   stop_id: "A17S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179785
#   }
#   departure {
#     time: 1714179785
#   }
#   stop_id: "A18S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179875
#   }
#   departure {
#     time: 1714179875
#   }
#   stop_id: "A19S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714179965
#   }
#   departure {
#     time: 1714179965
#   }
#   stop_id: "A20S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180055
#   }
#   departure {
#     time: 1714180055
#   }
#   stop_id: "A21S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180145
#   }
#   departure {
#     time: 1714180145
#   }
#   stop_id: "A22S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180235
#   }
#   departure {
#     time: 1714180235
#   }
#   stop_id: "A24S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A1"
#     actual_track: "A1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180355
#   }
#   departure {
#     time: 1714180355
#   }
#   stop_id: "D14S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180445
#   }
#   departure {
#     time: 1714180445
#   }
#   stop_id: "D15S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180535
#   }
#   departure {
#     time: 1714180535
#   }
#   stop_id: "D16S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180625
#   }
#   departure {
#     time: 1714180625
#   }
#   stop_id: "D17S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180805
#   }
#   departure {
#     time: 1714180805
#   }
#   stop_id: "D20S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714180925
#   }
#   departure {
#     time: 1714180925
#   }
#   stop_id: "D21S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181045
#   }
#   departure {
#     time: 1714181045
#   }
#   stop_id: "D22S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "B3"
#     actual_track: "B3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181525
#   }
#   departure {
#     time: 1714181525
#   }
#   stop_id: "R30S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181615
#   }
#   departure {
#     time: 1714181615
#   }
#   stop_id: "D24S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181765
#   }
#   departure {
#     time: 1714181765
#   }
#   stop_id: "D25S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182005
#   }
#   departure {
#     time: 1714182005
#   }
#   stop_id: "D26S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182125
#   }
#   departure {
#     time: 1714182125
#   }
#   stop_id: "D28S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182275
#   }
#   departure {
#     time: 1714182275
#   }
#   stop_id: "D31S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182575
#   }
#   departure {
#     time: 1714182575
#   }
#   stop_id: "D35S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182920
#   }
#   departure {
#     time: 1714182920
#   }
#   stop_id: "D39S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183085
#   }
#   departure {
#     time: 1714183085
#   }
#   stop_id: "D40S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "A3"
#     actual_track: "A3"
#   }
# }
#
# trip {
#   trip_id: "127500_B..S46R"
#   start_time: "21:15:00"
#   start_date: "20240426"
#   route_id: "B"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1B 2115 145/BBC"
#     direction: SOUTH
#   }
# }
# stop_time_update {
# ...
#   }
#   stop_id: "M11N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182150
#   }
#   departure {
#     time: 1714182150
#   }
#   stop_id: "M12N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182240
#   }
#   departure {
#     time: 1714182240
#   }
#   stop_id: "M13N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182300
#   }
#   departure {
#     time: 1714182300
#   }
#   stop_id: "M14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182360
#   }
#   departure {
#     time: 1714182360
#   }
#   stop_id: "M16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182900
#   }
#   departure {
#     time: 1714182900
#   }
#   stop_id: "M18N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "JM"
#     actual_track: "JM"
#   }
# }
#
# trip {
#   trip_id: "129500_M..N25R"
#   start_time: "21:35:00"
#   start_date: "20240426"
#   route_id: "M"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1M 2135 MET/ESX"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181700
#   }
#   departure {
#     time: 1714181700
#   }
#   stop_id: "M01N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181850
#   }
#   departure {
#     time: 1714181850
#   }
#   stop_id: "M04N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714181970
#   }
#   departure {
#     time: 1714181970
#   }
#   stop_id: "M05N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182060
#   }
#   departure {
#     time: 1714182060
#   }
#   stop_id: "M06N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182150
#   }
#   departure {
#     time: 1714182150
#   }
#   stop_id: "M08N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182270
#   }
#   departure {
#     time: 1714182270
#   }
#   stop_id: "M09N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182390
#   }
#   departure {
#     time: 1714182390
#   }
#   stop_id: "M10N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182540
#   }
#   departure {
#     time: 1714182540
#   }
#   stop_id: "M11N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182630
#   }
#   departure {
#     time: 1714182630
#   }
#   stop_id: "M12N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182720
#   }
#   departure {
#     time: 1714182720
#   }
#   stop_id: "M13N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182780
#   }
#   departure {
#     time: 1714182780
#   }
#   stop_id: "M14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182855
#   }
#   departure {
#     time: 1714182855
#   }
#   stop_id: "M16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183410
#   }
#   departure {
#     time: 1714183410
#   }
#   stop_id: "M18N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "JM"
#     actual_track: "JM"
#   }
# }
#
# trip {
#   trip_id: "130150_M..S25R"
#   start_time: "21:41:30"
#   start_date: "20240426"
#   route_id: "M"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1M 2141+ ESX/MET"
#     direction: SOUTH
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182090
#   }
#   departure {
#     time: 1714182090
#   }
#   stop_id: "M18S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "JM"
#     actual_track: "JM"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182540
#   }
#   departure {
#     time: 1714182540
#   }
#   stop_id: "M16S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J1"
#     actual_track: "J1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182600
#   }
#   departure {
#     time: 1714182600
#   }
#   stop_id: "M14S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J1"
#     actual_track: "J1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182690
#   }
#   departure {
#     time: 1714182690
#   }
#   stop_id: "M13S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J1"
#     actual_track: "J1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182780
#   }
#   departure {
#     time: 1714182780
#   }
#   stop_id: "M12S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J1"
#     actual_track: "J1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182840
#   }
#   departure {
#     time: 1714182840
#   }
#   stop_id: "M11S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J1"
#     actual_track: "J1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182960
#   }
#   departure {
#     time: 1714182960
#   }
#   stop_id: "M10S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183080
#   }
#   departure {
#     time: 1714183080
#   }
#   stop_id: "M09S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183170
#   }
#   departure {
#     time: 1714183170
#   }
#   stop_id: "M08S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183260
#   }
#   departure {
#     time: 1714183260
#   }
#   stop_id: "M06S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183350
#   }
#   departure {
#     time: 1714183350
#   }
#   stop_id: "M05S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183440
#   }
#   departure {
#     time: 1714183440
#   }
#   stop_id: "M04S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183590
#   }
#   departure {
#     time: 1714183590
#   }
#   stop_id: "M01S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
#
# trip {
#   trip_id: "130700_M..N25R"
#   start_time: "21:47:00"
#   start_date: "20240426"
#   route_id: "M"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1M 2147 MET/ESX"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182420
#   }
#   departure {
#     time: 1714182420
#   }
#   stop_id: "M01N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182570
#   }
#   departure {
#     time: 1714182570
#   }
#   stop_id: "M04N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182690
#   }
#   departure {
#     time: 1714182690
#   }
#   stop_id: "M05N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182780
#   }
#   departure {
#     time: 1714182780
#   }
#   stop_id: "M06N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182870
#   }
#   departure {
#     time: 1714182870
#   }
#   stop_id: "M08N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182990
#   }
#   departure {
#     time: 1714182990
#   }
#   stop_id: "M09N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183110
#   }
#   departure {
#     time: 1714183110
#   }
#   stop_id: "M10N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183260
#   }
#   departure {
#     time: 1714183260
#   }
#   stop_id: "M11N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183350
#   }
#   departure {
#     time: 1714183350
#   }
#   stop_id: "M12N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183440
#   }
#   departure {
#     time: 1714183440
#   }
#   stop_id: "M13N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183500
#   }
#   departure {
#     time: 1714183500
#   }
#   stop_id: "M14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183560
#   }
#   departure {
#     time: 1714183560
#   }
#   stop_id: "M16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714184100
#   }
#   departure {
#     time: 1714184100
#   }
#   stop_id: "M18N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "JM"
#     actual_track: "JM"
#   }
# }
#
# trip {
#   trip_id: "131150_M..S25R"
#   start_time: "21:51:30"
#   start_date: "20240426"
#   route_id: "M"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1M 2151+ ESX/MET"
#     direction: SOUTH
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714182690
#   }
#   departure {
#     time: 1714182690
#   }
#   stop_id: "M18S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "JM"
#     actual_track: "JM"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183140
#   }
#   departure {
#     time: 1714183140
#   }
#   stop_id: "M16S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J1"
#     actual_track: "J1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183200
#   }
#   departure {
#     time: 1714183200
#   }
#   stop_id: "M14S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J1"
#     actual_track: "J1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183290
#   }
#   departure {
#     time: 1714183290
#   }
#   stop_id: "M13S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J1"
#     actual_track: "J1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183380
#   }
#   departure {
#     time: 1714183380
#   }
#   stop_id: "M12S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J1"
#     actual_track: "J1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183440
#   }
#   departure {
#     time: 1714183440
#   }
#   stop_id: "M11S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J1"
#     actual_track: "J1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183560
#   }
#   departure {
#     time: 1714183560
#   }
#   stop_id: "M10S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183680
#   }
#   departure {
#     time: 1714183680
#   }
#   stop_id: "M09S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183770
#   }
#   departure {
#     time: 1714183770
#   }
#   stop_id: "M08S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183860
#   }
#   departure {
#     time: 1714183860
#   }
#   stop_id: "M06S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183950
#   }
#   departure {
#     time: 1714183950
#   }
#   stop_id: "M05S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714184040
#   }
#   departure {
#     time: 1714184040
#   }
#   stop_id: "M04S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714184190
#   }
#   departure {
#     time: 1714184190
#   }
#   stop_id: "M01S"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M1"
#     actual_track: "M1"
#   }
# }
#
# trip {
#   trip_id: "131700_M..N25R"
#   start_time: "21:57:00"
#   start_date: "20240426"
#   route_id: "M"
#   [transit_realtime.nyct_trip_descriptor] {
#     train_id: "1M 2157 MET/ESX"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183020
#   }
#   departure {
#     time: 1714183020
#   }
#   stop_id: "M01N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183170
#   }
#   departure {
#     time: 1714183170
#   }
#   stop_id: "M04N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183290
#   }
#   departure {
#     time: 1714183290
#   }
#   stop_id: "M05N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183380
#   }
#   departure {
#     time: 1714183380
#   }
#   stop_id: "M06N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183470
#   }
#   departure {
#     time: 1714183470
#   }
#   stop_id: "M08N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183590
#   }
#   departure {
#     time: 1714183590
#   }
#   stop_id: "M09N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183710
#   }
#   departure {
#     time: 1714183710
#   }
#   stop_id: "M10N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "M2"
#     actual_track: "M2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183860
#   }
#   departure {
#     time: 1714183860
#   }
#   stop_id: "M11N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714183950
#   }
#   departure {
#     time: 1714183950
#   }
#   stop_id: "M12N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714184040
#   }
#   departure {
#     time: 1714184040
#   }
#   stop_id: "M13N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714184100
#   }
#   departure {
#     time: 1714184100
#   }
#   stop_id: "M14N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714184160
#   }
#   departure {
#     time: 1714184160
#   }
#   stop_id: "M16N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "J2"
#     actual_track: "J2"
#   }
# }
# stop_time_update {
#   arrival {
#     time: 1714184700
#   }
#   departure {
#     time: 1714184700
#   }
#   stop_id: "M18N"
#   [transit_realtime.nyct_stop_time_update] {
#     scheduled_track: "JM"
#     actual_track: "JM"
#   }
# }

# %%
# -*- coding: utf-8 -*-
# Generated by the protocol buffer compiler.  DO NOT EDIT!
# source: nyct-subway.proto
# Protobuf Python Version: 4.25.1
"""Generated protocol buffer code."""

from google.protobuf import descriptor as _descriptor
from google.protobuf import descriptor_pool as _descriptor_pool
from google.protobuf import symbol_database as _symbol_database
from google.protobuf.internal import builder as _builder

# @@protoc_insertion_point(imports)

_sym_db = _symbol_database.Default()


from google.transit import gtfs_realtime_pb2

DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(
    b'\n\x11nyct-subway.proto\x12\x10transit_realtime\x1a\x13gtfs-realtime.proto"b\n\x15TripReplacementPeriod\x12\x10\n\x08route_id\x18\x01 \x01(\t\x12\x37\n\x12replacement_period\x18\x02 \x01(\x0b\x32\x1b.transit_realtime.TimeRange"w\n\x0eNyctFeedHeader\x12\x1b\n\x13nyct_subway_version\x18\x01 \x02(\t\x12H\n\x17trip_replacement_period\x18\x02 \x03(\x0b\x32\'.transit_realtime.TripReplacementPeriod"\xb5\x01\n\x12NyctTripDescriptor\x12\x10\n\x08train_id\x18\x01 \x01(\t\x12\x13\n\x0bis_assigned\x18\x02 \x01(\x08\x12\x41\n\tdirection\x18\x03 \x01(\x0e\x32..transit_realtime.NyctTripDescriptor.Direction"5\n\tDirection\x12\t\n\x05NORTH\x10\x01\x12\x08\n\x04\x45\x41ST\x10\x02\x12\t\n\x05SOUTH\x10\x03\x12\x08\n\x04WEST\x10\x04"C\n\x12NyctStopTimeUpdate\x12\x17\n\x0fscheduled_track\x18\x01 \x01(\t\x12\x14\n\x0c\x61\x63tual_track\x18\x02 \x01(\t:Y\n\x10nyct_feed_header\x12\x1c.transit_realtime.FeedHeader\x18\xe9\x07 \x01(\x0b\x32 .transit_realtime.NyctFeedHeader:e\n\x14nyct_trip_descriptor\x12 .transit_realtime.TripDescriptor\x18\xe9\x07 \x01(\x0b\x32$.transit_realtime.NyctTripDescriptor:q\n\x15nyct_stop_time_update\x12+.transit_realtime.TripUpdate.StopTimeUpdate\x18\xe9\x07 \x01(\x0b\x32$.transit_realtime.NyctStopTimeUpdateB\x1d\n\x1b\x63om.google.transit.realtime'
)

_globals = globals()
_builder.BuildMessageAndEnumDescriptors(DESCRIPTOR, _globals)
_builder.BuildTopDescriptorsAndMessages(DESCRIPTOR, "nyct_subway_pb2", _globals)
if _descriptor._USE_C_DESCRIPTORS == False:
    _globals["DESCRIPTOR"]._options = None
    _globals["DESCRIPTOR"]._serialized_options = b"\n\033com.google.transit.realtime"
    _globals["_TRIPREPLACEMENTPERIOD"]._serialized_start = 60
    _globals["_TRIPREPLACEMENTPERIOD"]._serialized_end = 158
    _globals["_NYCTFEEDHEADER"]._serialized_start = 160
    _globals["_NYCTFEEDHEADER"]._serialized_end = 279
    _globals["_NYCTTRIPDESCRIPTOR"]._serialized_start = 282
    _globals["_NYCTTRIPDESCRIPTOR"]._serialized_end = 463
    _globals["_NYCTTRIPDESCRIPTOR_DIRECTION"]._serialized_start = 410
    _globals["_NYCTTRIPDESCRIPTOR_DIRECTION"]._serialized_end = 463
    _globals["_NYCTSTOPTIMEUPDATE"]._serialized_start = 465
    _globals["_NYCTSTOPTIMEUPDATE"]._serialized_end = 532
# @@protoc_insertion_point(module_scope)

# %%
stops = pd.read_csv('./stops.csv')
stops.head()
# Out:
#   stop_id                  stop_name   stop_lat   stop_lon  location_type  \
# 0     101  Van Cortlandt Park-242 St  40.889248 -73.898583            1.0
# 1    101N  Van Cortlandt Park-242 St  40.889248 -73.898583            NaN
# 2    101S  Van Cortlandt Park-242 St  40.889248 -73.898583            NaN
# 3     103                     238 St  40.884667 -73.900870            1.0
# 4    103N                     238 St  40.884667 -73.900870            NaN
#
#   parent_station
# 0            NaN
# 1            101
# 2            101
# 3            NaN
# 4            103

# %%
stop_dict = {
    stop_id: {
        "stop_name": row["stop_name"],
        "stop_lat": row["stop_lat"],
        "stop_lon": row["stop_lon"]
    }
    for stop_id, row in stops.set_index('stop_id').iterrows()
}
stop_dict
# Out:
# {'101': {'stop_name': 'Van Cortlandt Park-242 St',
#   'stop_lat': 40.889248,
#   'stop_lon': -73.898583},
#  '101N': {'stop_name': 'Van Cortlandt Park-242 St',
#   'stop_lat': 40.889248,
#   'stop_lon': -73.898583},
#  '101S': {'stop_name': 'Van Cortlandt Park-242 St',
#   'stop_lat': 40.889248,
#   'stop_lon': -73.898583},
#  '103': {'stop_name': '238 St', 'stop_lat': 40.884667, 'stop_lon': -73.90087},
#  '103N': {'stop_name': '238 St', 'stop_lat': 40.884667, 'stop_lon': -73.90087},
#  '103S': {'stop_name': '238 St', 'stop_lat': 40.884667, 'stop_lon': -73.90087},
#  '104': {'stop_name': '231 St', 'stop_lat': 40.878856, 'stop_lon': -73.904834},
#  '104N': {'stop_name': '231 St',
#   'stop_lat': 40.878856,
#   'stop_lon': -73.904834},
#  '104S': {'stop_name': '231 St',
#   'stop_lat': 40.878856,
#   'stop_lon': -73.904834},
#  '106': {'stop_name': 'Marble Hill-225 St',
#   'stop_lat': 40.874561,
#   'stop_lon': -73.909831},
#  '106N': {'stop_name': 'Marble Hill-225 St',
#   'stop_lat': 40.874561,
#   'stop_lon': -73.909831},
#  '106S': {'stop_name': 'Marble Hill-225 St',
#   'stop_lat': 40.874561,
#   'stop_lon': -73.909831},
#  '107': {'stop_name': '215 St', 'stop_lat': 40.869444, 'stop_lon': -73.915279},
#  '107N': {'stop_name': '215 St',
#   'stop_lat': 40.869444,
#   'stop_lon': -73.915279},
#  '107S': {'stop_name': '215 St',
#   'stop_lat': 40.869444,
#   'stop_lon': -73.915279},
#  '108': {'stop_name': '207 St', 'stop_lat': 40.864621, 'stop_lon': -73.918822},
#  '108N': {'stop_name': '207 St',
#   'stop_lat': 40.864621,
#   'stop_lon': -73.918822},
#  '108S': {'stop_name': '207 St',
#   'stop_lat': 40.864621,
#   'stop_lon': -73.918822},
#  '109': {'stop_name': 'Dyckman St',
#   'stop_lat': 40.860531,
#   'stop_lon': -73.925536},
#  '109N': {'stop_name': 'Dyckman St',
#   'stop_lat': 40.860531,
#   'stop_lon': -73.925536},
#  '109S': {'stop_name': 'Dyckman St',
#   'stop_lat': 40.860531,
#   'stop_lon': -73.925536},
#  '110': {'stop_name': '191 St', 'stop_lat': 40.855225, 'stop_lon': -73.929412},
#  '110N': {'stop_name': '191 St',
#   'stop_lat': 40.855225,
#   'stop_lon': -73.929412},
#  '110S': {'stop_name': '191 St',
#   'stop_lat': 40.855225,
#   'stop_lon': -73.929412},
#  '111': {'stop_name': '181 St', 'stop_lat': 40.849505, 'stop_lon': -73.933596},
#  '111N': {'stop_name': '181 St',
#   'stop_lat': 40.849505,
#   'stop_lon': -73.933596},
#  '111S': {'stop_name': '181 St',
#   'stop_lat': 40.849505,
#   'stop_lon': -73.933596},
#  '112': {'stop_name': '168 St-Washington Hts',
#   'stop_lat': 40.840556,
#   'stop_lon': -73.940133},
#  '112N': {'stop_name': '168 St-Washington Hts',
#   'stop_lat': 40.840556,
#   'stop_lon': -73.940133},
#  '112S': {'stop_name': '168 St-Washington Hts',
#   'stop_lat': 40.840556,
#   'stop_lon': -73.940133},
#  '113': {'stop_name': '157 St', 'stop_lat': 40.834041, 'stop_lon': -73.94489},
#  '113N': {'stop_name': '157 St', 'stop_lat': 40.834041, 'stop_lon': -73.94489},
#  '113S': {'stop_name': '157 St', 'stop_lat': 40.834041, 'stop_lon': -73.94489},
#  '114': {'stop_name': '145 St', 'stop_lat': 40.826551, 'stop_lon': -73.95036},
#  '114N': {'stop_name': '145 St', 'stop_lat': 40.826551, 'stop_lon': -73.95036},
#  '114S': {'stop_name': '145 St', 'stop_lat': 40.826551, 'stop_lon': -73.95036},
#  '115': {'stop_name': '137 St-City College',
#   'stop_lat': 40.822008,
#   'stop_lon': -73.953676},
#  '115N': {'stop_name': '137 St-City College',
#   'stop_lat': 40.822008,
#   'stop_lon': -73.953676},
#  '115S': {'stop_name': '137 St-City College',
#   'stop_lat': 40.822008,
#   'stop_lon': -73.953676},
#  '116': {'stop_name': '125 St', 'stop_lat': 40.815581, 'stop_lon': -73.958372},
#  '116N': {'stop_name': '125 St',
#   'stop_lat': 40.815581,
#   'stop_lon': -73.958372},
#  '116S': {'stop_name': '125 St',
#   'stop_lat': 40.815581,
#   'stop_lon': -73.958372},
#  '117': {'stop_name': '116 St-Columbia University',
#   'stop_lat': 40.807722,
#   'stop_lon': -73.96411},
#  '117N': {'stop_name': '116 St-Columbia University',
#   'stop_lat': 40.807722,
#   'stop_lon': -73.96411},
#  '117S': {'stop_name': '116 St-Columbia University',
#   'stop_lat': 40.807722,
#   'stop_lon': -73.96411},
#  '118': {'stop_name': 'Cathedral Pkwy (110 St)',
#   'stop_lat': 40.803967,
#   'stop_lon': -73.966847},
#  '118N': {'stop_name': 'Cathedral Pkwy (110 St)',
#   'stop_lat': 40.803967,
#   'stop_lon': -73.966847},
#  '118S': {'stop_name': 'Cathedral Pkwy (110 St)',
#   'stop_lat': 40.803967,
#   'stop_lon': -73.966847},
#  '119': {'stop_name': '103 St', 'stop_lat': 40.799446, 'stop_lon': -73.968379},
#  '119N': {'stop_name': '103 St',
#   'stop_lat': 40.799446,
#   'stop_lon': -73.968379},
#  '119S': {'stop_name': '103 St',
#   'stop_lat': 40.799446,
#   'stop_lon': -73.968379},
#  '120': {'stop_name': '96 St', 'stop_lat': 40.793919, 'stop_lon': -73.972323},
#  '120N': {'stop_name': '96 St', 'stop_lat': 40.793919, 'stop_lon': -73.972323},
#  '120S': {'stop_name': '96 St', 'stop_lat': 40.793919, 'stop_lon': -73.972323},
#  '121': {'stop_name': '86 St', 'stop_lat': 40.788644, 'stop_lon': -73.976218},
#  '121N': {'stop_name': '86 St', 'stop_lat': 40.788644, 'stop_lon': -73.976218},
#  '121S': {'stop_name': '86 St', 'stop_lat': 40.788644, 'stop_lon': -73.976218},
#  '122': {'stop_name': '79 St', 'stop_lat': 40.783934, 'stop_lon': -73.979917},
#  '122N': {'stop_name': '79 St', 'stop_lat': 40.783934, 'stop_lon': -73.979917},
#  '122S': {'stop_name': '79 St', 'stop_lat': 40.783934, 'stop_lon': -73.979917},
#  '123': {'stop_name': '72 St', 'stop_lat': 40.778453, 'stop_lon': -73.98197},
#  '123N': {'stop_name': '72 St', 'stop_lat': 40.778453, 'stop_lon': -73.98197},
#  '123S': {'stop_name': '72 St', 'stop_lat': 40.778453, 'stop_lon': -73.98197},
#  '124': {'stop_name': '66 St-Lincoln Center',
#   'stop_lat': 40.77344,
#   'stop_lon': -73.982209},
#  '124N': {'stop_name': '66 St-Lincoln Center',
#   'stop_lat': 40.77344,
#   'stop_lon': -73.982209},
#  '124S': {'stop_name': '66 St-Lincoln Center',
#   'stop_lat': 40.77344,
#   'stop_lon': -73.982209},
#  '125': {'stop_name': '59 St-Columbus Circle',
#   'stop_lat': 40.768247,
#   'stop_lon': -73.981929},
#  '125N': {'stop_name': '59 St-Columbus Circle',
#   'stop_lat': 40.768247,
#   'stop_lon': -73.981929},
#  '125S': {'stop_name': '59 St-Columbus Circle',
#   'stop_lat': 40.768247,
#   'stop_lon': -73.981929},
#  '126': {'stop_name': '50 St', 'stop_lat': 40.761728, 'stop_lon': -73.983849},
#  '126N': {'stop_name': '50 St', 'stop_lat': 40.761728, 'stop_lon': -73.983849},
#  '126S': {'stop_name': '50 St', 'stop_lat': 40.761728, 'stop_lon': -73.983849},
#  '127': {'stop_name': 'Times Sq-42 St',
#   'stop_lat': 40.75529,
#   'stop_lon': -73.987495},
#  '127N': {'stop_name': 'Times Sq-42 St',
#   'stop_lat': 40.75529,
#   'stop_lon': -73.987495},
#  '127S': {'stop_name': 'Times Sq-42 St',
#   'stop_lat': 40.75529,
#   'stop_lon': -73.987495},
#  '128': {'stop_name': '34 St-Penn Station',
#   'stop_lat': 40.750373,
#   'stop_lon': -73.991057},
#  '128N': {'stop_name': '34 St-Penn Station',
#   'stop_lat': 40.750373,
#   'stop_lon': -73.991057},
#  '128S': {'stop_name': '34 St-Penn Station',
#   'stop_lat': 40.750373,
#   'stop_lon': -73.991057},
#  '129': {'stop_name': '28 St', 'stop_lat': 40.747215, 'stop_lon': -73.993365},
#  '129N': {'stop_name': '28 St', 'stop_lat': 40.747215, 'stop_lon': -73.993365},
#  '129S': {'stop_name': '28 St', 'stop_lat': 40.747215, 'stop_lon': -73.993365},
#  '130': {'stop_name': '23 St', 'stop_lat': 40.744081, 'stop_lon': -73.995657},
#  '130N': {'stop_name': '23 St', 'stop_lat': 40.744081, 'stop_lon': -73.995657},
#  '130S': {'stop_name': '23 St', 'stop_lat': 40.744081, 'stop_lon': -73.995657},
#  '131': {'stop_name': '18 St', 'stop_lat': 40.74104, 'stop_lon': -73.997871},
#  '131N': {'stop_name': '18 St', 'stop_lat': 40.74104, 'stop_lon': -73.997871},
#  '131S': {'stop_name': '18 St', 'stop_lat': 40.74104, 'stop_lon': -73.997871},
#  '132': {'stop_name': '14 St', 'stop_lat': 40.737826, 'stop_lon': -74.000201},
#  '132N': {'stop_name': '14 St', 'stop_lat': 40.737826, 'stop_lon': -74.000201},
#  '132S': {'stop_name': '14 St', 'stop_lat': 40.737826, 'stop_lon': -74.000201},
#  '133': {'stop_name': 'Christopher St-Sheridan Sq',
#   'stop_lat': 40.733422,
#   'stop_lon': -74.002906},
#  '133N': {'stop_name': 'Christopher St-Sheridan Sq',
#   'stop_lat': 40.733422,
#   'stop_lon': -74.002906},
#  '133S': {'stop_name': 'Christopher St-Sheridan Sq',
#   'stop_lat': 40.733422,
#   'stop_lon': -74.002906},
#  '134': {'stop_name': 'Houston St',
#   'stop_lat': 40.728251,
#   'stop_lon': -74.005367},
#  '134N': {'stop_name': 'Houston St',
#   'stop_lat': 40.728251,
#   'stop_lon': -74.005367},
#  '134S': {'stop_name': 'Houston St',
#   'stop_lat': 40.728251,
#   'stop_lon': -74.005367},
#  '135': {'stop_name': 'Canal St',
#   'stop_lat': 40.722854,
#   'stop_lon': -74.006277},
#  '135N': {'stop_name': 'Canal St',
#   'stop_lat': 40.722854,
#   'stop_lon': -74.006277},
#  '135S': {'stop_name': 'Canal St',
#   'stop_lat': 40.722854,
#   'stop_lon': -74.006277},
#  '136': {'stop_name': 'Franklin St',
#   'stop_lat': 40.719318,
#   'stop_lon': -74.006886},
#  '136N': {'stop_name': 'Franklin St',
#   'stop_lat': 40.719318,
#   'stop_lon': -74.006886},
#  '136S': {'stop_name': 'Franklin St',
#   'stop_lat': 40.719318,
#   'stop_lon': -74.006886},
#  '137': {'stop_name': 'Chambers St',
#   'stop_lat': 40.715478,
#   'stop_lon': -74.009266},
#  '137N': {'stop_name': 'Chambers St',
#   'stop_lat': 40.715478,
#   'stop_lon': -74.009266},
#  '137S': {'stop_name': 'Chambers St',
#   'stop_lat': 40.715478,
#   'stop_lon': -74.009266},
#  '138': {'stop_name': 'WTC Cortlandt',
#   'stop_lat': 40.711835,
#   'stop_lon': -74.012188},
#  '138N': {'stop_name': 'WTC Cortlandt',
#   'stop_lat': 40.711835,
#   'stop_lon': -74.012188},
#  '138S': {'stop_name': 'WTC Cortlandt',
#   'stop_lat': 40.711835,
#   'stop_lon': -74.012188},
#  '139': {'stop_name': 'Rector St',
#   'stop_lat': 40.707513,
#   'stop_lon': -74.013783},
#  '139N': {'stop_name': 'Rector St',
#   'stop_lat': 40.707513,
#   'stop_lon': -74.013783},
#  '139S': {'stop_name': 'Rector St',
#   'stop_lat': 40.707513,
#   'stop_lon': -74.013783},
#  '140': {'stop_name': 'South Ferry Loop',
#   'stop_lat': 40.701411,
#   'stop_lon': -74.013205},
#  '140N': {'stop_name': 'South Ferry Loop',
#   'stop_lat': 40.701411,
#   'stop_lon': -74.013205},
#  '140S': {'stop_name': 'South Ferry Loop',
#   'stop_lat': 40.701411,
#   'stop_lon': -74.013205},
#  '142': {'stop_name': 'South Ferry',
#   'stop_lat': 40.702068,
#   'stop_lon': -74.013664},
#  '142N': {'stop_name': 'South Ferry',
#   'stop_lat': 40.702068,
#   'stop_lon': -74.013664},
#  '142S': {'stop_name': 'South Ferry',
#   'stop_lat': 40.702068,
#   'stop_lon': -74.013664},
#  '201': {'stop_name': 'Wakefield-241 St',
#   'stop_lat': 40.903125,
#   'stop_lon': -73.85062},
#  '201N': {'stop_name': 'Wakefield-241 St',
#   'stop_lat': 40.903125,
#   'stop_lon': -73.85062},
#  '201S': {'stop_name': 'Wakefield-241 St',
#   'stop_lat': 40.903125,
#   'stop_lon': -73.85062},
#  '204': {'stop_name': 'Nereid Av',
#   'stop_lat': 40.898379,
#   'stop_lon': -73.854376},
#  '204N': {'stop_name': 'Nereid Av',
#   'stop_lat': 40.898379,
#   'stop_lon': -73.854376},
#  '204S': {'stop_name': 'Nereid Av',
#   'stop_lat': 40.898379,
#   'stop_lon': -73.854376},
#  '205': {'stop_name': '233 St', 'stop_lat': 40.893193, 'stop_lon': -73.857473},
#  '205N': {'stop_name': '233 St',
#   'stop_lat': 40.893193,
#   'stop_lon': -73.857473},
#  '205S': {'stop_name': '233 St',
#   'stop_lat': 40.893193,
#   'stop_lon': -73.857473},
#  '206': {'stop_name': '225 St', 'stop_lat': 40.888022, 'stop_lon': -73.860341},
#  '206N': {'stop_name': '225 St',
#   'stop_lat': 40.888022,
#   'stop_lon': -73.860341},
#  '206S': {'stop_name': '225 St',
#   'stop_lat': 40.888022,
#   'stop_lon': -73.860341},
#  '207': {'stop_name': '219 St', 'stop_lat': 40.883895, 'stop_lon': -73.862633},
#  '207N': {'stop_name': '219 St',
#   'stop_lat': 40.883895,
#   'stop_lon': -73.862633},
#  '207S': {'stop_name': '219 St',
#   'stop_lat': 40.883895,
#   'stop_lon': -73.862633},
#  '208': {'stop_name': 'Gun Hill Rd',
#   'stop_lat': 40.87785,
#   'stop_lon': -73.866256},
#  '208N': {'stop_name': 'Gun Hill Rd',
#   'stop_lat': 40.87785,
#   'stop_lon': -73.866256},
#  '208S': {'stop_name': 'Gun Hill Rd',
#   'stop_lat': 40.87785,
#   'stop_lon': -73.866256},
#  '209': {'stop_name': 'Burke Av',
#   'stop_lat': 40.871356,
#   'stop_lon': -73.867164},
#  '209N': {'stop_name': 'Burke Av',
#   'stop_lat': 40.871356,
#   'stop_lon': -73.867164},
#  '209S': {'stop_name': 'Burke Av',
#   'stop_lat': 40.871356,
#   'stop_lon': -73.867164},
#  '210': {'stop_name': 'Allerton Av',
#   'stop_lat': 40.865462,
#   'stop_lon': -73.867352},
#  '210N': {'stop_name': 'Allerton Av',
#   'stop_lat': 40.865462,
#   'stop_lon': -73.867352},
#  '210S': {'stop_name': 'Allerton Av',
#   'stop_lat': 40.865462,
#   'stop_lon': -73.867352},
#  '211': {'stop_name': 'Pelham Pkwy',
#   'stop_lat': 40.857192,
#   'stop_lon': -73.867615},
#  '211N': {'stop_name': 'Pelham Pkwy',
#   'stop_lat': 40.857192,
#   'stop_lon': -73.867615},
#  '211S': {'stop_name': 'Pelham Pkwy',
#   'stop_lat': 40.857192,
#   'stop_lon': -73.867615},
#  '212': {'stop_name': 'Bronx Park East',
#   'stop_lat': 40.848828,
#   'stop_lon': -73.868457},
#  '212N': {'stop_name': 'Bronx Park East',
#   'stop_lat': 40.848828,
#   'stop_lon': -73.868457},
#  '212S': {'stop_name': 'Bronx Park East',
#   'stop_lat': 40.848828,
#   'stop_lon': -73.868457},
#  '213': {'stop_name': 'E 180 St',
#   'stop_lat': 40.841894,
#   'stop_lon': -73.873488},
#  '213N': {'stop_name': 'E 180 St',
#   'stop_lat': 40.841894,
#   'stop_lon': -73.873488},
#  '213S': {'stop_name': 'E 180 St',
#   'stop_lat': 40.841894,
#   'stop_lon': -73.873488},
#  '214': {'stop_name': 'West Farms Sq-E Tremont Av',
#   'stop_lat': 40.840295,
#   'stop_lon': -73.880049},
#  '214N': {'stop_name': 'West Farms Sq-E Tremont Av',
#   'stop_lat': 40.840295,
#   'stop_lon': -73.880049},
#  '214S': {'stop_name': 'West Farms Sq-E Tremont Av',
#   'stop_lat': 40.840295,
#   'stop_lon': -73.880049},
#  '215': {'stop_name': '174 St', 'stop_lat': 40.837288, 'stop_lon': -73.887734},
#  '215N': {'stop_name': '174 St',
#   'stop_lat': 40.837288,
#   'stop_lon': -73.887734},
#  '215S': {'stop_name': '174 St',
#   'stop_lat': 40.837288,
#   'stop_lon': -73.887734},
#  '216': {'stop_name': 'Freeman St',
#   'stop_lat': 40.829993,
#   'stop_lon': -73.891865},
#  '216N': {'stop_name': 'Freeman St',
#   'stop_lat': 40.829993,
#   'stop_lon': -73.891865},
#  '216S': {'stop_name': 'Freeman St',
#   'stop_lat': 40.829993,
#   'stop_lon': -73.891865},
#  '217': {'stop_name': 'Simpson St',
#   'stop_lat': 40.824073,
#   'stop_lon': -73.893064},
#  '217N': {'stop_name': 'Simpson St',
#   'stop_lat': 40.824073,
#   'stop_lon': -73.893064},
#  '217S': {'stop_name': 'Simpson St',
#   'stop_lat': 40.824073,
#   'stop_lon': -73.893064},
#  '218': {'stop_name': 'Intervale Av',
#   'stop_lat': 40.822181,
#   'stop_lon': -73.896736},
#  '218N': {'stop_name': 'Intervale Av',
#   'stop_lat': 40.822181,
#   'stop_lon': -73.896736},
#  '218S': {'stop_name': 'Intervale Av',
#   'stop_lat': 40.822181,
#   'stop_lon': -73.896736},
#  '219': {'stop_name': 'Prospect Av',
#   'stop_lat': 40.819585,
#   'stop_lon': -73.90177},
#  '219N': {'stop_name': 'Prospect Av',
#   'stop_lat': 40.819585,
#   'stop_lon': -73.90177},
#  '219S': {'stop_name': 'Prospect Av',
#   'stop_lat': 40.819585,
#   'stop_lon': -73.90177},
#  '220': {'stop_name': 'Jackson Av',
#   'stop_lat': 40.81649,
#   'stop_lon': -73.907807},
#  '220N': {'stop_name': 'Jackson Av',
#   'stop_lat': 40.81649,
#   'stop_lon': -73.907807},
#  '220S': {'stop_name': 'Jackson Av',
#   'stop_lat': 40.81649,
#   'stop_lon': -73.907807},
#  '221': {'stop_name': '3 Av-149 St',
#   'stop_lat': 40.816109,
#   'stop_lon': -73.917757},
#  '221N': {'stop_name': '3 Av-149 St',
#   'stop_lat': 40.816109,
#   'stop_lon': -73.917757},
#  '221S': {'stop_name': '3 Av-149 St',
#   'stop_lat': 40.816109,
#   'stop_lon': -73.917757},
#  '222': {'stop_name': '149 St-Grand Concourse',
#   'stop_lat': 40.81841,
#   'stop_lon': -73.926718},
#  '222N': {'stop_name': '149 St-Grand Concourse',
#   'stop_lat': 40.81841,
#   'stop_lon': -73.926718},
#  '222S': {'stop_name': '149 St-Grand Concourse',
#   'stop_lat': 40.81841,
#   'stop_lon': -73.926718},
#  '224': {'stop_name': '135 St', 'stop_lat': 40.814229, 'stop_lon': -73.94077},
#  '224N': {'stop_name': '135 St', 'stop_lat': 40.814229, 'stop_lon': -73.94077},
#  '224S': {'stop_name': '135 St', 'stop_lat': 40.814229, 'stop_lon': -73.94077},
#  '225': {'stop_name': '125 St', 'stop_lat': 40.807754, 'stop_lon': -73.945495},
#  '225N': {'stop_name': '125 St',
#   'stop_lat': 40.807754,
#   'stop_lon': -73.945495},
#  '225S': {'stop_name': '125 St',
#   'stop_lat': 40.807754,
#   'stop_lon': -73.945495},
#  '226': {'stop_name': '116 St', 'stop_lat': 40.802098, 'stop_lon': -73.949625},
#  '226N': {'stop_name': '116 St',
#   'stop_lat': 40.802098,
#   'stop_lon': -73.949625},
#  '226S': {'stop_name': '116 St',
#   'stop_lat': 40.802098,
#   'stop_lon': -73.949625},
#  '227': {'stop_name': 'Central Park North (110 St)',
#   'stop_lat': 40.799075,
#   'stop_lon': -73.951822},
#  '227N': {'stop_name': 'Central Park North (110 St)',
#   'stop_lat': 40.799075,
#   'stop_lon': -73.951822},
#  '227S': {'stop_name': 'Central Park North (110 St)',
#   'stop_lat': 40.799075,
#   'stop_lon': -73.951822},
#  '228': {'stop_name': 'Park Place',
#   'stop_lat': 40.713051,
#   'stop_lon': -74.008811},
#  '228N': {'stop_name': 'Park Place',
#   'stop_lat': 40.713051,
#   'stop_lon': -74.008811},
#  '228S': {'stop_name': 'Park Place',
#   'stop_lat': 40.713051,
#   'stop_lon': -74.008811},
#  '229': {'stop_name': 'Fulton St',
#   'stop_lat': 40.709416,
#   'stop_lon': -74.006571},
#  '229N': {'stop_name': 'Fulton St',
#   'stop_lat': 40.709416,
#   'stop_lon': -74.006571},
#  '229S': {'stop_name': 'Fulton St',
#   'stop_lat': 40.709416,
#   'stop_lon': -74.006571},
#  '230': {'stop_name': 'Wall St', 'stop_lat': 40.706821, 'stop_lon': -74.0091},
#  '230N': {'stop_name': 'Wall St', 'stop_lat': 40.706821, 'stop_lon': -74.0091},
#  '230S': {'stop_name': 'Wall St', 'stop_lat': 40.706821, 'stop_lon': -74.0091},
#  '231': {'stop_name': 'Clark St',
#   'stop_lat': 40.697466,
#   'stop_lon': -73.993086},
#  '231N': {'stop_name': 'Clark St',
#   'stop_lat': 40.697466,
#   'stop_lon': -73.993086},
#  '231S': {'stop_name': 'Clark St',
#   'stop_lat': 40.697466,
#   'stop_lon': -73.993086},
#  '232': {'stop_name': 'Borough Hall',
#   'stop_lat': 40.693219,
#   'stop_lon': -73.989998},
#  '232N': {'stop_name': 'Borough Hall',
#   'stop_lat': 40.693219,
#   'stop_lon': -73.989998},
#  '232S': {'stop_name': 'Borough Hall',
#   'stop_lat': 40.693219,
#   'stop_lon': -73.989998},
#  '233': {'stop_name': 'Hoyt St',
#   'stop_lat': 40.690545,
#   'stop_lon': -73.985065},
#  '233N': {'stop_name': 'Hoyt St',
#   'stop_lat': 40.690545,
#   'stop_lon': -73.985065},
#  '233S': {'stop_name': 'Hoyt St',
#   'stop_lat': 40.690545,
#   'stop_lon': -73.985065},
#  '234': {'stop_name': 'Nevins St',
#   'stop_lat': 40.688246,
#   'stop_lon': -73.980492},
#  '234N': {'stop_name': 'Nevins St',
#   'stop_lat': 40.688246,
#   'stop_lon': -73.980492},
#  '234S': {'stop_name': 'Nevins St',
#   'stop_lat': 40.688246,
#   'stop_lon': -73.980492},
#  '235': {'stop_name': 'Atlantic Av-Barclays Ctr',
#   'stop_lat': 40.684359,
#   'stop_lon': -73.977666},
#  '235N': {'stop_name': 'Atlantic Av-Barclays Ctr',
#   'stop_lat': 40.684359,
#   'stop_lon': -73.977666},
#  '235S': {'stop_name': 'Atlantic Av-Barclays Ctr',
#   'stop_lat': 40.684359,
#   'stop_lon': -73.977666},
#  '236': {'stop_name': 'Bergen St',
#   'stop_lat': 40.680829,
#   'stop_lon': -73.975098},
#  '236N': {'stop_name': 'Bergen St',
#   'stop_lat': 40.680829,
#   'stop_lon': -73.975098},
#  '236S': {'stop_name': 'Bergen St',
#   'stop_lat': 40.680829,
#   'stop_lon': -73.975098},
#  '237': {'stop_name': 'Grand Army Plaza',
#   'stop_lat': 40.675235,
#   'stop_lon': -73.971046},
#  '237N': {'stop_name': 'Grand Army Plaza',
#   'stop_lat': 40.675235,
#   'stop_lon': -73.971046},
#  '237S': {'stop_name': 'Grand Army Plaza',
#   'stop_lat': 40.675235,
#   'stop_lon': -73.971046},
#  '238': {'stop_name': 'Eastern Pkwy-Brooklyn Museum',
#   'stop_lat': 40.671987,
#   'stop_lon': -73.964375},
#  '238N': {'stop_name': 'Eastern Pkwy-Brooklyn Museum',
#   'stop_lat': 40.671987,
#   'stop_lon': -73.964375},
#  '238S': {'stop_name': 'Eastern Pkwy-Brooklyn Museum',
#   'stop_lat': 40.671987,
#   'stop_lon': -73.964375},
#  '239': {'stop_name': 'Franklin Av-Medgar Evers College',
#   'stop_lat': 40.670682,
#   'stop_lon': -73.958131},
#  '239N': {'stop_name': 'Franklin Av-Medgar Evers College',
#   'stop_lat': 40.670682,
#   'stop_lon': -73.958131},
#  '239S': {'stop_name': 'Franklin Av-Medgar Evers College',
#   'stop_lat': 40.670682,
#   'stop_lon': -73.958131},
#  '241': {'stop_name': 'President St-Medgar Evers College',
#   'stop_lat': 40.667883,
#   'stop_lon': -73.950683},
#  '241N': {'stop_name': 'President St-Medgar Evers College',
#   'stop_lat': 40.667883,
#   'stop_lon': -73.950683},
#  '241S': {'stop_name': 'President St-Medgar Evers College',
#   'stop_lat': 40.667883,
#   'stop_lon': -73.950683},
#  '242': {'stop_name': 'Sterling St',
#   'stop_lat': 40.662742,
#   'stop_lon': -73.95085},
#  '242N': {'stop_name': 'Sterling St',
#   'stop_lat': 40.662742,
#   'stop_lon': -73.95085},
#  '242S': {'stop_name': 'Sterling St',
#   'stop_lat': 40.662742,
#   'stop_lon': -73.95085},
#  '243': {'stop_name': 'Winthrop St',
#   'stop_lat': 40.656652,
#   'stop_lon': -73.9502},
#  '243N': {'stop_name': 'Winthrop St',
#   'stop_lat': 40.656652,
#   'stop_lon': -73.9502},
#  '243S': {'stop_name': 'Winthrop St',
#   'stop_lat': 40.656652,
#   'stop_lon': -73.9502},
#  '244': {'stop_name': 'Church Av',
#   'stop_lat': 40.650843,
#   'stop_lon': -73.949575},
#  '244N': {'stop_name': 'Church Av',
#   'stop_lat': 40.650843,
#   'stop_lon': -73.949575},
#  '244S': {'stop_name': 'Church Av',
#   'stop_lat': 40.650843,
#   'stop_lon': -73.949575},
#  '245': {'stop_name': 'Beverly Rd',
#   'stop_lat': 40.645098,
#   'stop_lon': -73.948959},
#  '245N': {'stop_name': 'Beverly Rd',
#   'stop_lat': 40.645098,
#   'stop_lon': -73.948959},
#  '245S': {'stop_name': 'Beverly Rd',
#   'stop_lat': 40.645098,
#   'stop_lon': -73.948959},
#  '246': {'stop_name': 'Newkirk Av-Little Haiti',
#   'stop_lat': 40.639967,
#   'stop_lon': -73.948411},
#  '246N': {'stop_name': 'Newkirk Av-Little Haiti',
#   'stop_lat': 40.639967,
#   'stop_lon': -73.948411},
#  '246S': {'stop_name': 'Newkirk Av-Little Haiti',
#   'stop_lat': 40.639967,
#   'stop_lon': -73.948411},
#  '247': {'stop_name': 'Flatbush Av-Brooklyn College',
#   'stop_lat': 40.632836,
#   'stop_lon': -73.947642},
#  '247N': {'stop_name': 'Flatbush Av-Brooklyn College',
#   'stop_lat': 40.632836,
#   'stop_lon': -73.947642},
#  '247S': {'stop_name': 'Flatbush Av-Brooklyn College',
#   'stop_lat': 40.632836,
#   'stop_lon': -73.947642},
#  '248': {'stop_name': 'Nostrand Av',
#   'stop_lat': 40.669847,
#   'stop_lon': -73.950466},
#  '248N': {'stop_name': 'Nostrand Av',
#   'stop_lat': 40.669847,
#   'stop_lon': -73.950466},
#  '248S': {'stop_name': 'Nostrand Av',
#   'stop_lat': 40.669847,
#   'stop_lon': -73.950466},
#  '249': {'stop_name': 'Kingston Av',
#   'stop_lat': 40.669399,
#   'stop_lon': -73.942161},
#  '249N': {'stop_name': 'Kingston Av',
#   'stop_lat': 40.669399,
#   'stop_lon': -73.942161},
#  '249S': {'stop_name': 'Kingston Av',
#   'stop_lat': 40.669399,
#   'stop_lon': -73.942161},
#  '250': {'stop_name': 'Crown Hts-Utica Av',
#   'stop_lat': 40.668897,
#   'stop_lon': -73.932942},
#  '250N': {'stop_name': 'Crown Hts-Utica Av',
#   'stop_lat': 40.668897,
#   'stop_lon': -73.932942},
#  '250S': {'stop_name': 'Crown Hts-Utica Av',
#   'stop_lat': 40.668897,
#   'stop_lon': -73.932942},
#  '251': {'stop_name': 'Sutter Av-Rutland Rd',
#   'stop_lat': 40.664717,
#   'stop_lon': -73.92261},
#  '251N': {'stop_name': 'Sutter Av-Rutland Rd',
#   'stop_lat': 40.664717,
#   'stop_lon': -73.92261},
#  '251S': {'stop_name': 'Sutter Av-Rutland Rd',
#   'stop_lat': 40.664717,
#   'stop_lon': -73.92261},
#  '252': {'stop_name': 'Saratoga Av',
#   'stop_lat': 40.661453,
#   'stop_lon': -73.916327},
#  '252N': {'stop_name': 'Saratoga Av',
#   'stop_lat': 40.661453,
#   'stop_lon': -73.916327},
#  '252S': {'stop_name': 'Saratoga Av',
#   'stop_lat': 40.661453,
#   'stop_lon': -73.916327},
#  '253': {'stop_name': 'Rockaway Av',
#   'stop_lat': 40.662549,
#   'stop_lon': -73.908946},
#  '253N': {'stop_name': 'Rockaway Av',
#   'stop_lat': 40.662549,
#   'stop_lon': -73.908946},
#  '253S': {'stop_name': 'Rockaway Av',
#   'stop_lat': 40.662549,
#   'stop_lon': -73.908946},
#  '254': {'stop_name': 'Junius St',
#   'stop_lat': 40.663515,
#   'stop_lon': -73.902447},
#  '254N': {'stop_name': 'Junius St',
#   'stop_lat': 40.663515,
#   'stop_lon': -73.902447},
#  '254S': {'stop_name': 'Junius St',
#   'stop_lat': 40.663515,
#   'stop_lon': -73.902447},
#  '255': {'stop_name': 'Pennsylvania Av',
#   'stop_lat': 40.664635,
#   'stop_lon': -73.894895},
#  '255N': {'stop_name': 'Pennsylvania Av',
#   'stop_lat': 40.664635,
#   'stop_lon': -73.894895},
#  '255S': {'stop_name': 'Pennsylvania Av',
#   'stop_lat': 40.664635,
#   'stop_lon': -73.894895},
#  '256': {'stop_name': 'Van Siclen Av',
#   'stop_lat': 40.665449,
#   'stop_lon': -73.889395},
#  '256N': {'stop_name': 'Van Siclen Av',
#   'stop_lat': 40.665449,
#   'stop_lon': -73.889395},
#  '256S': {'stop_name': 'Van Siclen Av',
#   'stop_lat': 40.665449,
#   'stop_lon': -73.889395},
#  '257': {'stop_name': 'New Lots Av',
#   'stop_lat': 40.666235,
#   'stop_lon': -73.884079},
#  '257N': {'stop_name': 'New Lots Av',
#   'stop_lat': 40.666235,
#   'stop_lon': -73.884079},
#  '257S': {'stop_name': 'New Lots Av',
#   'stop_lat': 40.666235,
#   'stop_lon': -73.884079},
#  '301': {'stop_name': 'Harlem-148 St',
#   'stop_lat': 40.82388,
#   'stop_lon': -73.93647},
#  '301N': {'stop_name': 'Harlem-148 St',
#   'stop_lat': 40.82388,
#   'stop_lon': -73.93647},
#  '301S': {'stop_name': 'Harlem-148 St',
#   'stop_lat': 40.82388,
#   'stop_lon': -73.93647},
#  '302': {'stop_name': '145 St', 'stop_lat': 40.820421, 'stop_lon': -73.936245},
#  '302N': {'stop_name': '145 St',
#   'stop_lat': 40.820421,
#   'stop_lon': -73.936245},
#  '302S': {'stop_name': '145 St',
#   'stop_lat': 40.820421,
#   'stop_lon': -73.936245},
#  '401': {'stop_name': 'Woodlawn',
#   'stop_lat': 40.886037,
#   'stop_lon': -73.878751},
#  '401N': {'stop_name': 'Woodlawn',
#   'stop_lat': 40.886037,
#   'stop_lon': -73.878751},
#  '401S': {'stop_name': 'Woodlawn',
#   'stop_lat': 40.886037,
#   'stop_lon': -73.878751},
#  '402': {'stop_name': 'Mosholu Pkwy',
#   'stop_lat': 40.87975,
#   'stop_lon': -73.884655},
#  '402N': {'stop_name': 'Mosholu Pkwy',
#   'stop_lat': 40.87975,
#   'stop_lon': -73.884655},
#  '402S': {'stop_name': 'Mosholu Pkwy',
#   'stop_lat': 40.87975,
#   'stop_lon': -73.884655},
#  '405': {'stop_name': 'Bedford Park Blvd-Lehman College',
#   'stop_lat': 40.873412,
#   'stop_lon': -73.890064},
#  '405N': {'stop_name': 'Bedford Park Blvd-Lehman College',
#   'stop_lat': 40.873412,
#   'stop_lon': -73.890064},
#  '405S': {'stop_name': 'Bedford Park Blvd-Lehman College',
#   'stop_lat': 40.873412,
#   'stop_lon': -73.890064},
#  '406': {'stop_name': 'Kingsbridge Rd',
#   'stop_lat': 40.86776,
#   'stop_lon': -73.897174},
#  '406N': {'stop_name': 'Kingsbridge Rd',
#   'stop_lat': 40.86776,
#   'stop_lon': -73.897174},
#  '406S': {'stop_name': 'Kingsbridge Rd',
#   'stop_lat': 40.86776,
#   'stop_lon': -73.897174},
#  '407': {'stop_name': 'Fordham Rd',
#   'stop_lat': 40.862803,
#   'stop_lon': -73.901034},
#  '407N': {'stop_name': 'Fordham Rd',
#   'stop_lat': 40.862803,
#   'stop_lon': -73.901034},
#  '407S': {'stop_name': 'Fordham Rd',
#   'stop_lat': 40.862803,
#   'stop_lon': -73.901034},
#  '408': {'stop_name': '183 St', 'stop_lat': 40.858407, 'stop_lon': -73.903879},
#  '408N': {'stop_name': '183 St',
#   'stop_lat': 40.858407,
#   'stop_lon': -73.903879},
#  '408S': {'stop_name': '183 St',
#   'stop_lat': 40.858407,
#   'stop_lon': -73.903879},
#  '409': {'stop_name': 'Burnside Av',
#   'stop_lat': 40.853453,
#   'stop_lon': -73.907684},
#  '409N': {'stop_name': 'Burnside Av',
#   'stop_lat': 40.853453,
#   'stop_lon': -73.907684},
#  '409S': {'stop_name': 'Burnside Av',
#   'stop_lat': 40.853453,
#   'stop_lon': -73.907684},
#  '410': {'stop_name': '176 St', 'stop_lat': 40.84848, 'stop_lon': -73.911794},
#  '410N': {'stop_name': '176 St', 'stop_lat': 40.84848, 'stop_lon': -73.911794},
#  '410S': {'stop_name': '176 St', 'stop_lat': 40.84848, 'stop_lon': -73.911794},
#  '411': {'stop_name': 'Mt Eden Av',
#   'stop_lat': 40.844434,
#   'stop_lon': -73.914685},
#  '411N': {'stop_name': 'Mt Eden Av',
#   'stop_lat': 40.844434,
#   'stop_lon': -73.914685},
#  '411S': {'stop_name': 'Mt Eden Av',
#   'stop_lat': 40.844434,
#   'stop_lon': -73.914685},
#  '412': {'stop_name': '170 St', 'stop_lat': 40.840075, 'stop_lon': -73.917791},
#  '412N': {'stop_name': '170 St',
#   'stop_lat': 40.840075,
#   'stop_lon': -73.917791},
#  '412S': {'stop_name': '170 St',
#   'stop_lat': 40.840075,
#   'stop_lon': -73.917791},
#  '413': {'stop_name': '167 St', 'stop_lat': 40.835537, 'stop_lon': -73.9214},
#  '413N': {'stop_name': '167 St', 'stop_lat': 40.835537, 'stop_lon': -73.9214},
#  '413S': {'stop_name': '167 St', 'stop_lat': 40.835537, 'stop_lon': -73.9214},
#  '414': {'stop_name': '161 St-Yankee Stadium',
#   'stop_lat': 40.827994,
#   'stop_lon': -73.925831},
#  '414N': {'stop_name': '161 St-Yankee Stadium',
#   'stop_lat': 40.827994,
#   'stop_lon': -73.925831},
#  '414S': {'stop_name': '161 St-Yankee Stadium',
#   'stop_lat': 40.827994,
#   'stop_lon': -73.925831},
#  '415': {'stop_name': '149 St-Grand Concourse',
#   'stop_lat': 40.818375,
#   'stop_lon': -73.927351},
#  '415N': {'stop_name': '149 St-Grand Concourse',
#   'stop_lat': 40.818375,
#   'stop_lon': -73.927351},
#  '415S': {'stop_name': '149 St-Grand Concourse',
#   'stop_lat': 40.818375,
#   'stop_lon': -73.927351},
#  '416': {'stop_name': '138 St-Grand Concourse',
#   'stop_lat': 40.813224,
#   'stop_lon': -73.929849},
#  '416N': {'stop_name': '138 St-Grand Concourse',
#   'stop_lat': 40.813224,
#   'stop_lon': -73.929849},
#  '416S': {'stop_name': '138 St-Grand Concourse',
#   'stop_lat': 40.813224,
#   'stop_lon': -73.929849},
#  '418': {'stop_name': 'Fulton St',
#   'stop_lat': 40.710368,
#   'stop_lon': -74.009509},
#  '418N': {'stop_name': 'Fulton St',
#   'stop_lat': 40.710368,
#   'stop_lon': -74.009509},
#  '418S': {'stop_name': 'Fulton St',
#   'stop_lat': 40.710368,
#   'stop_lon': -74.009509},
#  '419': {'stop_name': 'Wall St',
#   'stop_lat': 40.707557,
#   'stop_lon': -74.011862},
#  '419N': {'stop_name': 'Wall St',
#   'stop_lat': 40.707557,
#   'stop_lon': -74.011862},
#  '419S': {'stop_name': 'Wall St',
#   'stop_lat': 40.707557,
#   'stop_lon': -74.011862},
#  '420': {'stop_name': 'Bowling Green',
#   'stop_lat': 40.704817,
#   'stop_lon': -74.014065},
#  '420N': {'stop_name': 'Bowling Green',
#   'stop_lat': 40.704817,
#   'stop_lon': -74.014065},
#  '420S': {'stop_name': 'Bowling Green',
#   'stop_lat': 40.704817,
#   'stop_lon': -74.014065},
#  '423': {'stop_name': 'Borough Hall',
#   'stop_lat': 40.692404,
#   'stop_lon': -73.990151},
#  '423N': {'stop_name': 'Borough Hall',
#   'stop_lat': 40.692404,
#   'stop_lon': -73.990151},
#  '423S': {'stop_name': 'Borough Hall',
#   'stop_lat': 40.692404,
#   'stop_lon': -73.990151},
#  '501': {'stop_name': 'Eastchester-Dyre Av',
#   'stop_lat': 40.8883,
#   'stop_lon': -73.830834},
#  '501N': {'stop_name': 'Eastchester-Dyre Av',
#   'stop_lat': 40.8883,
#   'stop_lon': -73.830834},
#  '501S': {'stop_name': 'Eastchester-Dyre Av',
#   'stop_lat': 40.8883,
#   'stop_lon': -73.830834},
#  '502': {'stop_name': 'Baychester Av',
#   'stop_lat': 40.878663,
#   'stop_lon': -73.838591},
#  '502N': {'stop_name': 'Baychester Av',
#   'stop_lat': 40.878663,
#   'stop_lon': -73.838591},
#  '502S': {'stop_name': 'Baychester Av',
#   'stop_lat': 40.878663,
#   'stop_lon': -73.838591},
#  '503': {'stop_name': 'Gun Hill Rd',
#   'stop_lat': 40.869526,
#   'stop_lon': -73.846384},
#  '503N': {'stop_name': 'Gun Hill Rd',
#   'stop_lat': 40.869526,
#   'stop_lon': -73.846384},
#  '503S': {'stop_name': 'Gun Hill Rd',
#   'stop_lat': 40.869526,
#   'stop_lon': -73.846384},
#  '504': {'stop_name': 'Pelham Pkwy',
#   'stop_lat': 40.858985,
#   'stop_lon': -73.855359},
#  '504N': {'stop_name': 'Pelham Pkwy',
#   'stop_lat': 40.858985,
#   'stop_lon': -73.855359},
#  '504S': {'stop_name': 'Pelham Pkwy',
#   'stop_lat': 40.858985,
#   'stop_lon': -73.855359},
#  '505': {'stop_name': 'Morris Park',
#   'stop_lat': 40.854364,
#   'stop_lon': -73.860495},
#  '505N': {'stop_name': 'Morris Park',
#   'stop_lat': 40.854364,
#   'stop_lon': -73.860495},
#  '505S': {'stop_name': 'Morris Park',
#   'stop_lat': 40.854364,
#   'stop_lon': -73.860495},
#  '601': {'stop_name': 'Pelham Bay Park',
#   'stop_lat': 40.852462,
#   'stop_lon': -73.828121},
#  '601N': {'stop_name': 'Pelham Bay Park',
#   'stop_lat': 40.852462,
#   'stop_lon': -73.828121},
#  '601S': {'stop_name': 'Pelham Bay Park',
#   'stop_lat': 40.852462,
#   'stop_lon': -73.828121},
#  '602': {'stop_name': 'Buhre Av',
#   'stop_lat': 40.84681,
#   'stop_lon': -73.832569},
#  '602N': {'stop_name': 'Buhre Av',
#   'stop_lat': 40.84681,
#   'stop_lon': -73.832569},
#  '602S': {'stop_name': 'Buhre Av',
#   'stop_lat': 40.84681,
#   'stop_lon': -73.832569},
#  '603': {'stop_name': 'Middletown Rd',
#   'stop_lat': 40.843863,
#   'stop_lon': -73.836322},
#  '603N': {'stop_name': 'Middletown Rd',
#   'stop_lat': 40.843863,
#   'stop_lon': -73.836322},
#  '603S': {'stop_name': 'Middletown Rd',
#   'stop_lat': 40.843863,
#   'stop_lon': -73.836322},
#  '604': {'stop_name': 'Westchester Sq-E Tremont Av',
#   'stop_lat': 40.839892,
#   'stop_lon': -73.842952},
#  '604N': {'stop_name': 'Westchester Sq-E Tremont Av',
#   'stop_lat': 40.839892,
#   'stop_lon': -73.842952},
#  '604S': {'stop_name': 'Westchester Sq-E Tremont Av',
#   'stop_lat': 40.839892,
#   'stop_lon': -73.842952},
#  '606': {'stop_name': 'Zerega Av',
#   'stop_lat': 40.836488,
#   'stop_lon': -73.847036},
#  '606N': {'stop_name': 'Zerega Av',
#   'stop_lat': 40.836488,
#   'stop_lon': -73.847036},
#  '606S': {'stop_name': 'Zerega Av',
#   'stop_lat': 40.836488,
#   'stop_lon': -73.847036},
#  '607': {'stop_name': 'Castle Hill Av',
#   'stop_lat': 40.834255,
#   'stop_lon': -73.851222},
#  '607N': {'stop_name': 'Castle Hill Av',
#   'stop_lat': 40.834255,
#   'stop_lon': -73.851222},
#  '607S': {'stop_name': 'Castle Hill Av',
#   'stop_lat': 40.834255,
#   'stop_lon': -73.851222},
#  '608': {'stop_name': 'Parkchester',
#   'stop_lat': 40.833226,
#   'stop_lon': -73.860816},
#  '608N': {'stop_name': 'Parkchester',
#   'stop_lat': 40.833226,
#   'stop_lon': -73.860816},
#  '608S': {'stop_name': 'Parkchester',
#   'stop_lat': 40.833226,
#   'stop_lon': -73.860816},
#  '609': {'stop_name': 'St Lawrence Av',
#   'stop_lat': 40.831509,
#   'stop_lon': -73.867618},
#  '609N': {'stop_name': 'St Lawrence Av',
#   'stop_lat': 40.831509,
#   'stop_lon': -73.867618},
#  '609S': {'stop_name': 'St Lawrence Av',
#   'stop_lat': 40.831509,
#   'stop_lon': -73.867618},
#  '610': {'stop_name': 'Morrison Av-Soundview',
#   'stop_lat': 40.829521,
#   'stop_lon': -73.874516},
#  '610N': {'stop_name': 'Morrison Av-Soundview',
#   'stop_lat': 40.829521,
#   'stop_lon': -73.874516},
#  '610S': {'stop_name': 'Morrison Av-Soundview',
#   'stop_lat': 40.829521,
#   'stop_lon': -73.874516},
#  '611': {'stop_name': 'Elder Av',
#   'stop_lat': 40.828584,
#   'stop_lon': -73.879159},
#  '611N': {'stop_name': 'Elder Av',
#   'stop_lat': 40.828584,
#   'stop_lon': -73.879159},
#  '611S': {'stop_name': 'Elder Av',
#   'stop_lat': 40.828584,
#   'stop_lon': -73.879159},
#  '612': {'stop_name': 'Whitlock Av',
#   'stop_lat': 40.826525,
#   'stop_lon': -73.886283},
#  '612N': {'stop_name': 'Whitlock Av',
#   'stop_lat': 40.826525,
#   'stop_lon': -73.886283},
#  '612S': {'stop_name': 'Whitlock Av',
#   'stop_lat': 40.826525,
#   'stop_lon': -73.886283},
#  '613': {'stop_name': 'Hunts Point Av',
#   'stop_lat': 40.820948,
#   'stop_lon': -73.890549},
#  '613N': {'stop_name': 'Hunts Point Av',
#   'stop_lat': 40.820948,
#   'stop_lon': -73.890549},
#  '613S': {'stop_name': 'Hunts Point Av',
#   'stop_lat': 40.820948,
#   'stop_lon': -73.890549},
#  '614': {'stop_name': 'Longwood Av',
#   'stop_lat': 40.816104,
#   'stop_lon': -73.896435},
#  '614N': {'stop_name': 'Longwood Av',
#   'stop_lat': 40.816104,
#   'stop_lon': -73.896435},
#  '614S': {'stop_name': 'Longwood Av',
#   'stop_lat': 40.816104,
#   'stop_lon': -73.896435},
#  '615': {'stop_name': 'E 149 St',
#   'stop_lat': 40.812118,
#   'stop_lon': -73.904098},
#  '615N': {'stop_name': 'E 149 St',
#   'stop_lat': 40.812118,
#   'stop_lon': -73.904098},
#  '615S': {'stop_name': 'E 149 St',
#   'stop_lat': 40.812118,
#   'stop_lon': -73.904098},
#  '616': {'stop_name': "E 143 St-St Mary's St",
#   'stop_lat': 40.808719,
#   'stop_lon': -73.907657},
#  '616N': {'stop_name': "E 143 St-St Mary's St",
#   'stop_lat': 40.808719,
#   'stop_lon': -73.907657},
#  '616S': {'stop_name': "E 143 St-St Mary's St",
#   'stop_lat': 40.808719,
#   'stop_lon': -73.907657},
#  '617': {'stop_name': 'Cypress Av',
#   'stop_lat': 40.805368,
#   'stop_lon': -73.914042},
#  '617N': {'stop_name': 'Cypress Av',
#   'stop_lat': 40.805368,
#   'stop_lon': -73.914042},
#  '617S': {'stop_name': 'Cypress Av',
#   'stop_lat': 40.805368,
#   'stop_lon': -73.914042},
#  '618': {'stop_name': 'Brook Av',
#   'stop_lat': 40.807566,
#   'stop_lon': -73.91924},
#  '618N': {'stop_name': 'Brook Av',
#   'stop_lat': 40.807566,
#   'stop_lon': -73.91924},
#  '618S': {'stop_name': 'Brook Av',
#   'stop_lat': 40.807566,
#   'stop_lon': -73.91924},
#  '619': {'stop_name': '3 Av-138 St',
#   'stop_lat': 40.810476,
#   'stop_lon': -73.926138},
#  '619N': {'stop_name': '3 Av-138 St',
#   'stop_lat': 40.810476,
#   'stop_lon': -73.926138},
#  '619S': {'stop_name': '3 Av-138 St',
#   'stop_lat': 40.810476,
#   'stop_lon': -73.926138},
#  '621': {'stop_name': '125 St', 'stop_lat': 40.804138, 'stop_lon': -73.937594},
#  '621N': {'stop_name': '125 St',
#   'stop_lat': 40.804138,
#   'stop_lon': -73.937594},
#  '621S': {'stop_name': '125 St',
#   'stop_lat': 40.804138,
#   'stop_lon': -73.937594},
#  '622': {'stop_name': '116 St', 'stop_lat': 40.798629, 'stop_lon': -73.941617},
#  '622N': {'stop_name': '116 St',
#   'stop_lat': 40.798629,
#   'stop_lon': -73.941617},
#  '622S': {'stop_name': '116 St',
#   'stop_lat': 40.798629,
#   'stop_lon': -73.941617},
#  '623': {'stop_name': '110 St', 'stop_lat': 40.79502, 'stop_lon': -73.94425},
#  '623N': {'stop_name': '110 St', 'stop_lat': 40.79502, 'stop_lon': -73.94425},
#  '623S': {'stop_name': '110 St', 'stop_lat': 40.79502, 'stop_lon': -73.94425},
#  '624': {'stop_name': '103 St', 'stop_lat': 40.7906, 'stop_lon': -73.947478},
#  '624N': {'stop_name': '103 St', 'stop_lat': 40.7906, 'stop_lon': -73.947478},
#  '624S': {'stop_name': '103 St', 'stop_lat': 40.7906, 'stop_lon': -73.947478},
#  '625': {'stop_name': '96 St', 'stop_lat': 40.785672, 'stop_lon': -73.95107},
#  '625N': {'stop_name': '96 St', 'stop_lat': 40.785672, 'stop_lon': -73.95107},
#  '625S': {'stop_name': '96 St', 'stop_lat': 40.785672, 'stop_lon': -73.95107},
#  '626': {'stop_name': '86 St', 'stop_lat': 40.779492, 'stop_lon': -73.955589},
#  '626N': {'stop_name': '86 St', 'stop_lat': 40.779492, 'stop_lon': -73.955589},
#  '626S': {'stop_name': '86 St', 'stop_lat': 40.779492, 'stop_lon': -73.955589},
#  '627': {'stop_name': '77 St', 'stop_lat': 40.77362, 'stop_lon': -73.959874},
#  '627N': {'stop_name': '77 St', 'stop_lat': 40.77362, 'stop_lon': -73.959874},
#  '627S': {'stop_name': '77 St', 'stop_lat': 40.77362, 'stop_lon': -73.959874},
#  '628': {'stop_name': '68 St-Hunter College',
#   'stop_lat': 40.768141,
#   'stop_lon': -73.96387},
#  '628N': {'stop_name': '68 St-Hunter College',
#   'stop_lat': 40.768141,
#   'stop_lon': -73.96387},
#  '628S': {'stop_name': '68 St-Hunter College',
#   'stop_lat': 40.768141,
#   'stop_lon': -73.96387},
#  '629': {'stop_name': '59 St', 'stop_lat': 40.762526, 'stop_lon': -73.967967},
#  '629N': {'stop_name': '59 St', 'stop_lat': 40.762526, 'stop_lon': -73.967967},
#  '629S': {'stop_name': '59 St', 'stop_lat': 40.762526, 'stop_lon': -73.967967},
#  '630': {'stop_name': '51 St', 'stop_lat': 40.757107, 'stop_lon': -73.97192},
#  '630N': {'stop_name': '51 St', 'stop_lat': 40.757107, 'stop_lon': -73.97192},
#  '630S': {'stop_name': '51 St', 'stop_lat': 40.757107, 'stop_lon': -73.97192},
#  '631': {'stop_name': 'Grand Central-42 St',
#   'stop_lat': 40.751776,
#   'stop_lon': -73.976848},
#  '631N': {'stop_name': 'Grand Central-42 St',
#   'stop_lat': 40.751776,
#   'stop_lon': -73.976848},
#  '631S': {'stop_name': 'Grand Central-42 St',
#   'stop_lat': 40.751776,
#   'stop_lon': -73.976848},
#  '632': {'stop_name': '33 St', 'stop_lat': 40.746081, 'stop_lon': -73.982076},
#  '632N': {'stop_name': '33 St', 'stop_lat': 40.746081, 'stop_lon': -73.982076},
#  '632S': {'stop_name': '33 St', 'stop_lat': 40.746081, 'stop_lon': -73.982076},
#  '633': {'stop_name': '28 St', 'stop_lat': 40.74307, 'stop_lon': -73.984264},
#  '633N': {'stop_name': '28 St', 'stop_lat': 40.74307, 'stop_lon': -73.984264},
#  '633S': {'stop_name': '28 St', 'stop_lat': 40.74307, 'stop_lon': -73.984264},
#  '634': {'stop_name': '23 St', 'stop_lat': 40.739864, 'stop_lon': -73.986599},
#  '634N': {'stop_name': '23 St', 'stop_lat': 40.739864, 'stop_lon': -73.986599},
#  '634S': {'stop_name': '23 St', 'stop_lat': 40.739864, 'stop_lon': -73.986599},
#  '635': {'stop_name': '14 St-Union Sq',
#   'stop_lat': 40.734673,
#   'stop_lon': -73.989951},
#  '635N': {'stop_name': '14 St-Union Sq',
#   'stop_lat': 40.734673,
#   'stop_lon': -73.989951},
#  '635S': {'stop_name': '14 St-Union Sq',
#   'stop_lat': 40.734673,
#   'stop_lon': -73.989951},
#  '636': {'stop_name': 'Astor Pl',
#   'stop_lat': 40.730054,
#   'stop_lon': -73.99107},
#  '636N': {'stop_name': 'Astor Pl',
#   'stop_lat': 40.730054,
#   'stop_lon': -73.99107},
#  '636S': {'stop_name': 'Astor Pl',
#   'stop_lat': 40.730054,
#   'stop_lon': -73.99107},
#  '637': {'stop_name': 'Bleecker St',
#   'stop_lat': 40.725915,
#   'stop_lon': -73.994659},
#  '637N': {'stop_name': 'Bleecker St',
#   'stop_lat': 40.725915,
#   'stop_lon': -73.994659},
#  '637S': {'stop_name': 'Bleecker St',
#   'stop_lat': 40.725915,
#   'stop_lon': -73.994659},
#  '638': {'stop_name': 'Spring St',
#   'stop_lat': 40.722301,
#   'stop_lon': -73.997141},
#  '638N': {'stop_name': 'Spring St',
#   'stop_lat': 40.722301,
#   'stop_lon': -73.997141},
#  '638S': {'stop_name': 'Spring St',
#   'stop_lat': 40.722301,
#   'stop_lon': -73.997141},
#  '639': {'stop_name': 'Canal St',
#   'stop_lat': 40.718803,
#   'stop_lon': -74.000193},
#  '639N': {'stop_name': 'Canal St',
#   'stop_lat': 40.718803,
#   'stop_lon': -74.000193},
#  '639S': {'stop_name': 'Canal St',
#   'stop_lat': 40.718803,
#   'stop_lon': -74.000193},
#  '640': {'stop_name': 'Brooklyn Bridge-City Hall',
#   'stop_lat': 40.713065,
#   'stop_lon': -74.004131},
#  '640N': {'stop_name': 'Brooklyn Bridge-City Hall',
#   'stop_lat': 40.713065,
#   'stop_lon': -74.004131},
#  '640S': {'stop_name': 'Brooklyn Bridge-City Hall',
#   'stop_lat': 40.713065,
#   'stop_lon': -74.004131},
#  '701': {'stop_name': 'Flushing-Main St',
#   'stop_lat': 40.7596,
#   'stop_lon': -73.83003},
#  '701N': {'stop_name': 'Flushing-Main St',
#   'stop_lat': 40.7596,
#   'stop_lon': -73.83003},
#  '701S': {'stop_name': 'Flushing-Main St',
#   'stop_lat': 40.7596,
#   'stop_lon': -73.83003},
#  '702': {'stop_name': 'Mets-Willets Point',
#   'stop_lat': 40.754622,
#   'stop_lon': -73.845625},
#  '702N': {'stop_name': 'Mets-Willets Point',
#   'stop_lat': 40.754622,
#   'stop_lon': -73.845625},
#  '702S': {'stop_name': 'Mets-Willets Point',
#   'stop_lat': 40.754622,
#   'stop_lon': -73.845625},
#  '705': {'stop_name': '111 St', 'stop_lat': 40.75173, 'stop_lon': -73.855334},
#  '705N': {'stop_name': '111 St', 'stop_lat': 40.75173, 'stop_lon': -73.855334},
#  '705S': {'stop_name': '111 St', 'stop_lat': 40.75173, 'stop_lon': -73.855334},
#  '706': {'stop_name': '103 St-Corona Plaza',
#   'stop_lat': 40.749865,
#   'stop_lon': -73.8627},
#  '706N': {'stop_name': '103 St-Corona Plaza',
#   'stop_lat': 40.749865,
#   'stop_lon': -73.8627},
#  '706S': {'stop_name': '103 St-Corona Plaza',
#   'stop_lat': 40.749865,
#   'stop_lon': -73.8627},
#  '707': {'stop_name': 'Junction Blvd',
#   'stop_lat': 40.749145,
#   'stop_lon': -73.869527},
#  '707N': {'stop_name': 'Junction Blvd',
#   'stop_lat': 40.749145,
#   'stop_lon': -73.869527},
#  '707S': {'stop_name': 'Junction Blvd',
#   'stop_lat': 40.749145,
#   'stop_lon': -73.869527},
#  '708': {'stop_name': '90 St-Elmhurst Av',
#   'stop_lat': 40.748408,
#   'stop_lon': -73.876613},
#  '708N': {'stop_name': '90 St-Elmhurst Av',
#   'stop_lat': 40.748408,
#   'stop_lon': -73.876613},
#  '708S': {'stop_name': '90 St-Elmhurst Av',
#   'stop_lat': 40.748408,
#   'stop_lon': -73.876613},
#  '709': {'stop_name': '82 St-Jackson Hts',
#   'stop_lat': 40.747659,
#   'stop_lon': -73.883697},
#  '709N': {'stop_name': '82 St-Jackson Hts',
#   'stop_lat': 40.747659,
#   'stop_lon': -73.883697},
#  '709S': {'stop_name': '82 St-Jackson Hts',
#   'stop_lat': 40.747659,
#   'stop_lon': -73.883697},
#  '710': {'stop_name': '74 St-Broadway',
#   'stop_lat': 40.746848,
#   'stop_lon': -73.891394},
#  '710N': {'stop_name': '74 St-Broadway',
#   'stop_lat': 40.746848,
#   'stop_lon': -73.891394},
#  '710S': {'stop_name': '74 St-Broadway',
#   'stop_lat': 40.746848,
#   'stop_lon': -73.891394},
#  '711': {'stop_name': '69 St', 'stop_lat': 40.746325, 'stop_lon': -73.896403},
#  '711N': {'stop_name': '69 St', 'stop_lat': 40.746325, 'stop_lon': -73.896403},
#  '711S': {'stop_name': '69 St', 'stop_lat': 40.746325, 'stop_lon': -73.896403},
#  '712': {'stop_name': '61 St-Woodside',
#   'stop_lat': 40.74563,
#   'stop_lon': -73.902984},
#  '712N': {'stop_name': '61 St-Woodside',
#   'stop_lat': 40.74563,
#   'stop_lon': -73.902984},
#  '712S': {'stop_name': '61 St-Woodside',
#   'stop_lat': 40.74563,
#   'stop_lon': -73.902984},
#  '713': {'stop_name': '52 St', 'stop_lat': 40.744149, 'stop_lon': -73.912549},
#  '713N': {'stop_name': '52 St', 'stop_lat': 40.744149, 'stop_lon': -73.912549},
#  '713S': {'stop_name': '52 St', 'stop_lat': 40.744149, 'stop_lon': -73.912549},
#  '714': {'stop_name': '46 St-Bliss St',
#   'stop_lat': 40.743132,
#   'stop_lon': -73.918435},
#  '714N': {'stop_name': '46 St-Bliss St',
#   'stop_lat': 40.743132,
#   'stop_lon': -73.918435},
#  '714S': {'stop_name': '46 St-Bliss St',
#   'stop_lat': 40.743132,
#   'stop_lon': -73.918435},
#  '715': {'stop_name': '40 St-Lowery St',
#   'stop_lat': 40.743781,
#   'stop_lon': -73.924016},
#  '715N': {'stop_name': '40 St-Lowery St',
#   'stop_lat': 40.743781,
#   'stop_lon': -73.924016},
#  '715S': {'stop_name': '40 St-Lowery St',
#   'stop_lat': 40.743781,
#   'stop_lon': -73.924016},
#  '716': {'stop_name': '33 St-Rawson St',
#   'stop_lat': 40.744587,
#   'stop_lon': -73.930997},
#  '716N': {'stop_name': '33 St-Rawson St',
#   'stop_lat': 40.744587,
#   'stop_lon': -73.930997},
#  '716S': {'stop_name': '33 St-Rawson St',
#   'stop_lat': 40.744587,
#   'stop_lon': -73.930997},
#  '718': {'stop_name': 'Queensboro Plaza',
#   'stop_lat': 40.750582,
#   'stop_lon': -73.940202},
#  '718N': {'stop_name': 'Queensboro Plaza',
#   'stop_lat': 40.750582,
#   'stop_lon': -73.940202},
#  '718S': {'stop_name': 'Queensboro Plaza',
#   'stop_lat': 40.750582,
#   'stop_lon': -73.940202},
#  '719': {'stop_name': 'Court Sq',
#   'stop_lat': 40.747023,
#   'stop_lon': -73.945264},
#  '719N': {'stop_name': 'Court Sq',
#   'stop_lat': 40.747023,
#   'stop_lon': -73.945264},
#  '719S': {'stop_name': 'Court Sq',
#   'stop_lat': 40.747023,
#   'stop_lon': -73.945264},
#  '720': {'stop_name': 'Hunters Point Av',
#   'stop_lat': 40.742216,
#   'stop_lon': -73.948916},
#  '720N': {'stop_name': 'Hunters Point Av',
#   'stop_lat': 40.742216,
#   'stop_lon': -73.948916},
#  '720S': {'stop_name': 'Hunters Point Av',
#   'stop_lat': 40.742216,
#   'stop_lon': -73.948916},
#  '721': {'stop_name': 'Vernon Blvd-Jackson Av',
#   'stop_lat': 40.742626,
#   'stop_lon': -73.953581},
#  '721N': {'stop_name': 'Vernon Blvd-Jackson Av',
#   'stop_lat': 40.742626,
#   'stop_lon': -73.953581},
#  '721S': {'stop_name': 'Vernon Blvd-Jackson Av',
#   'stop_lat': 40.742626,
#   'stop_lon': -73.953581},
#  '723': {'stop_name': 'Grand Central-42 St',
#   'stop_lat': 40.751431,
#   'stop_lon': -73.976041},
#  '723N': {'stop_name': 'Grand Central-42 St',
#   'stop_lat': 40.751431,
#   'stop_lon': -73.976041},
#  '723S': {'stop_name': 'Grand Central-42 St',
#   'stop_lat': 40.751431,
#   'stop_lon': -73.976041},
#  '724': {'stop_name': '5 Av', 'stop_lat': 40.753821, 'stop_lon': -73.981963},
#  '724N': {'stop_name': '5 Av', 'stop_lat': 40.753821, 'stop_lon': -73.981963},
#  '724S': {'stop_name': '5 Av', 'stop_lat': 40.753821, 'stop_lon': -73.981963},
#  '725': {'stop_name': 'Times Sq-42 St',
#   'stop_lat': 40.755477,
#   'stop_lon': -73.987691},
#  '725N': {'stop_name': 'Times Sq-42 St',
#   'stop_lat': 40.755477,
#   'stop_lon': -73.987691},
#  '725S': {'stop_name': 'Times Sq-42 St',
#   'stop_lat': 40.755477,
#   'stop_lon': -73.987691},
#  '726': {'stop_name': '34 St-Hudson Yards',
#   'stop_lat': 40.755882,
#   'stop_lon': -74.00191},
#  '726N': {'stop_name': '34 St-Hudson Yards',
#   'stop_lat': 40.755882,
#   'stop_lon': -74.00191},
#  '726S': {'stop_name': '34 St-Hudson Yards',
#   'stop_lat': 40.755882,
#   'stop_lon': -74.00191},
#  '901': {'stop_name': 'Grand Central-42 St',
#   'stop_lat': 40.752769,
#   'stop_lon': -73.979189},
#  '901N': {'stop_name': 'Grand Central-42 St',
#   'stop_lat': 40.752769,
#   'stop_lon': -73.979189},
#  '901S': {'stop_name': 'Grand Central-42 St',
#   'stop_lat': 40.752769,
#   'stop_lon': -73.979189},
# ...
#   'stop_lat': 40.640927,
#   'stop_lon': -73.963891},
#  'D30N': {'stop_name': 'Cortelyou Rd',
#   'stop_lat': 40.640927,
#   'stop_lon': -73.963891},
#  'D30S': {'stop_name': 'Cortelyou Rd',
#   'stop_lat': 40.640927,
#   'stop_lon': -73.963891},
#  'D31': {'stop_name': 'Newkirk Plaza',
#   'stop_lat': 40.635082,
#   'stop_lon': -73.962793},
#  'D31N': {'stop_name': 'Newkirk Plaza',
#   'stop_lat': 40.635082,
#   'stop_lon': -73.962793},
#  'D31S': {'stop_name': 'Newkirk Plaza',
#   'stop_lat': 40.635082,
#   'stop_lon': -73.962793},
#  'D32': {'stop_name': 'Avenue H',
#   'stop_lat': 40.62927,
#   'stop_lon': -73.961639},
#  'D32N': {'stop_name': 'Avenue H',
#   'stop_lat': 40.62927,
#   'stop_lon': -73.961639},
#  'D32S': {'stop_name': 'Avenue H',
#   'stop_lat': 40.62927,
#   'stop_lon': -73.961639},
#  'D33': {'stop_name': 'Avenue J',
#   'stop_lat': 40.625039,
#   'stop_lon': -73.960803},
#  'D33N': {'stop_name': 'Avenue J',
#   'stop_lat': 40.625039,
#   'stop_lon': -73.960803},
#  'D33S': {'stop_name': 'Avenue J',
#   'stop_lat': 40.625039,
#   'stop_lon': -73.960803},
#  'D34': {'stop_name': 'Avenue M',
#   'stop_lat': 40.617618,
#   'stop_lon': -73.959399},
#  'D34N': {'stop_name': 'Avenue M',
#   'stop_lat': 40.617618,
#   'stop_lon': -73.959399},
#  'D34S': {'stop_name': 'Avenue M',
#   'stop_lat': 40.617618,
#   'stop_lon': -73.959399},
#  'D35': {'stop_name': 'Kings Hwy',
#   'stop_lat': 40.60867,
#   'stop_lon': -73.957734},
#  'D35N': {'stop_name': 'Kings Hwy',
#   'stop_lat': 40.60867,
#   'stop_lon': -73.957734},
#  'D35S': {'stop_name': 'Kings Hwy',
#   'stop_lat': 40.60867,
#   'stop_lon': -73.957734},
#  'D37': {'stop_name': 'Avenue U', 'stop_lat': 40.5993, 'stop_lon': -73.955929},
#  'D37N': {'stop_name': 'Avenue U',
#   'stop_lat': 40.5993,
#   'stop_lon': -73.955929},
#  'D37S': {'stop_name': 'Avenue U',
#   'stop_lat': 40.5993,
#   'stop_lon': -73.955929},
#  'D38': {'stop_name': 'Neck Rd',
#   'stop_lat': 40.595246,
#   'stop_lon': -73.955161},
#  'D38N': {'stop_name': 'Neck Rd',
#   'stop_lat': 40.595246,
#   'stop_lon': -73.955161},
#  'D38S': {'stop_name': 'Neck Rd',
#   'stop_lat': 40.595246,
#   'stop_lon': -73.955161},
#  'D39': {'stop_name': 'Sheepshead Bay',
#   'stop_lat': 40.586896,
#   'stop_lon': -73.954155},
#  'D39N': {'stop_name': 'Sheepshead Bay',
#   'stop_lat': 40.586896,
#   'stop_lon': -73.954155},
#  'D39S': {'stop_name': 'Sheepshead Bay',
#   'stop_lat': 40.586896,
#   'stop_lon': -73.954155},
#  'D40': {'stop_name': 'Brighton Beach',
#   'stop_lat': 40.577621,
#   'stop_lon': -73.961376},
#  'D40N': {'stop_name': 'Brighton Beach',
#   'stop_lat': 40.577621,
#   'stop_lon': -73.961376},
#  'D40S': {'stop_name': 'Brighton Beach',
#   'stop_lat': 40.577621,
#   'stop_lon': -73.961376},
#  'D41': {'stop_name': 'Ocean Pkwy',
#   'stop_lat': 40.576312,
#   'stop_lon': -73.968501},
#  'D41N': {'stop_name': 'Ocean Pkwy',
#   'stop_lat': 40.576312,
#   'stop_lon': -73.968501},
#  'D41S': {'stop_name': 'Ocean Pkwy',
#   'stop_lat': 40.576312,
#   'stop_lon': -73.968501},
#  'D42': {'stop_name': 'W 8 St-NY Aquarium',
#   'stop_lat': 40.576127,
#   'stop_lon': -73.975939},
#  'D42N': {'stop_name': 'W 8 St-NY Aquarium',
#   'stop_lat': 40.576127,
#   'stop_lon': -73.975939},
#  'D42S': {'stop_name': 'W 8 St-NY Aquarium',
#   'stop_lat': 40.576127,
#   'stop_lon': -73.975939},
#  'D43': {'stop_name': 'Coney Island-Stillwell Av',
#   'stop_lat': 40.577422,
#   'stop_lon': -73.981233},
#  'D43N': {'stop_name': 'Coney Island-Stillwell Av',
#   'stop_lat': 40.577422,
#   'stop_lon': -73.981233},
#  'D43S': {'stop_name': 'Coney Island-Stillwell Av',
#   'stop_lat': 40.577422,
#   'stop_lon': -73.981233},
#  'E01': {'stop_name': 'World Trade Center',
#   'stop_lat': 40.712582,
#   'stop_lon': -74.009781},
#  'E01N': {'stop_name': 'World Trade Center',
#   'stop_lat': 40.712582,
#   'stop_lon': -74.009781},
#  'E01S': {'stop_name': 'World Trade Center',
#   'stop_lat': 40.712582,
#   'stop_lon': -74.009781},
#  'F01': {'stop_name': 'Jamaica-179 St',
#   'stop_lat': 40.712646,
#   'stop_lon': -73.783817},
#  'F01N': {'stop_name': 'Jamaica-179 St',
#   'stop_lat': 40.712646,
#   'stop_lon': -73.783817},
#  'F01S': {'stop_name': 'Jamaica-179 St',
#   'stop_lat': 40.712646,
#   'stop_lon': -73.783817},
#  'F02': {'stop_name': '169 St', 'stop_lat': 40.71047, 'stop_lon': -73.793604},
#  'F02N': {'stop_name': '169 St', 'stop_lat': 40.71047, 'stop_lon': -73.793604},
#  'F02S': {'stop_name': '169 St', 'stop_lat': 40.71047, 'stop_lon': -73.793604},
#  'F03': {'stop_name': 'Parsons Blvd',
#   'stop_lat': 40.707564,
#   'stop_lon': -73.803326},
#  'F03N': {'stop_name': 'Parsons Blvd',
#   'stop_lat': 40.707564,
#   'stop_lon': -73.803326},
#  'F03S': {'stop_name': 'Parsons Blvd',
#   'stop_lat': 40.707564,
#   'stop_lon': -73.803326},
#  'F04': {'stop_name': 'Sutphin Blvd',
#   'stop_lat': 40.70546,
#   'stop_lon': -73.810708},
#  'F04N': {'stop_name': 'Sutphin Blvd',
#   'stop_lat': 40.70546,
#   'stop_lon': -73.810708},
#  'F04S': {'stop_name': 'Sutphin Blvd',
#   'stop_lat': 40.70546,
#   'stop_lon': -73.810708},
#  'F05': {'stop_name': 'Briarwood',
#   'stop_lat': 40.709179,
#   'stop_lon': -73.820574},
#  'F05N': {'stop_name': 'Briarwood',
#   'stop_lat': 40.709179,
#   'stop_lon': -73.820574},
#  'F05S': {'stop_name': 'Briarwood',
#   'stop_lat': 40.709179,
#   'stop_lon': -73.820574},
#  'F06': {'stop_name': 'Kew Gardens-Union Tpke',
#   'stop_lat': 40.714441,
#   'stop_lon': -73.831008},
#  'F06N': {'stop_name': 'Kew Gardens-Union Tpke',
#   'stop_lat': 40.714441,
#   'stop_lon': -73.831008},
#  'F06S': {'stop_name': 'Kew Gardens-Union Tpke',
#   'stop_lat': 40.714441,
#   'stop_lon': -73.831008},
#  'F07': {'stop_name': '75 Av', 'stop_lat': 40.718331, 'stop_lon': -73.837324},
#  'F07N': {'stop_name': '75 Av', 'stop_lat': 40.718331, 'stop_lon': -73.837324},
#  'F07S': {'stop_name': '75 Av', 'stop_lat': 40.718331, 'stop_lon': -73.837324},
#  'F09': {'stop_name': 'Court Sq-23 St',
#   'stop_lat': 40.747846,
#   'stop_lon': -73.946},
#  'F09N': {'stop_name': 'Court Sq-23 St',
#   'stop_lat': 40.747846,
#   'stop_lon': -73.946},
#  'F09S': {'stop_name': 'Court Sq-23 St',
#   'stop_lat': 40.747846,
#   'stop_lon': -73.946},
#  'F11': {'stop_name': 'Lexington Av/53 St',
#   'stop_lat': 40.757552,
#   'stop_lon': -73.969055},
#  'F11N': {'stop_name': 'Lexington Av/53 St',
#   'stop_lat': 40.757552,
#   'stop_lon': -73.969055},
#  'F11S': {'stop_name': 'Lexington Av/53 St',
#   'stop_lat': 40.757552,
#   'stop_lon': -73.969055},
#  'F12': {'stop_name': '5 Av/53 St',
#   'stop_lat': 40.760167,
#   'stop_lon': -73.975224},
#  'F12N': {'stop_name': '5 Av/53 St',
#   'stop_lat': 40.760167,
#   'stop_lon': -73.975224},
#  'F12S': {'stop_name': '5 Av/53 St',
#   'stop_lat': 40.760167,
#   'stop_lon': -73.975224},
#  'F14': {'stop_name': '2 Av', 'stop_lat': 40.723402, 'stop_lon': -73.989938},
#  'F14N': {'stop_name': '2 Av', 'stop_lat': 40.723402, 'stop_lon': -73.989938},
#  'F14S': {'stop_name': '2 Av', 'stop_lat': 40.723402, 'stop_lon': -73.989938},
#  'F15': {'stop_name': 'Delancey St-Essex St',
#   'stop_lat': 40.718611,
#   'stop_lon': -73.988114},
#  'F15N': {'stop_name': 'Delancey St-Essex St',
#   'stop_lat': 40.718611,
#   'stop_lon': -73.988114},
#  'F15S': {'stop_name': 'Delancey St-Essex St',
#   'stop_lat': 40.718611,
#   'stop_lon': -73.988114},
#  'F16': {'stop_name': 'East Broadway',
#   'stop_lat': 40.713715,
#   'stop_lon': -73.990173},
#  'F16N': {'stop_name': 'East Broadway',
#   'stop_lat': 40.713715,
#   'stop_lon': -73.990173},
#  'F16S': {'stop_name': 'East Broadway',
#   'stop_lat': 40.713715,
#   'stop_lon': -73.990173},
#  'F18': {'stop_name': 'York St',
#   'stop_lat': 40.701397,
#   'stop_lon': -73.986751},
#  'F18N': {'stop_name': 'York St',
#   'stop_lat': 40.701397,
#   'stop_lon': -73.986751},
#  'F18S': {'stop_name': 'York St',
#   'stop_lat': 40.701397,
#   'stop_lon': -73.986751},
#  'F20': {'stop_name': 'Bergen St',
#   'stop_lat': 40.686145,
#   'stop_lon': -73.990862},
#  'F20N': {'stop_name': 'Bergen St',
#   'stop_lat': 40.686145,
#   'stop_lon': -73.990862},
#  'F20S': {'stop_name': 'Bergen St',
#   'stop_lat': 40.686145,
#   'stop_lon': -73.990862},
#  'F21': {'stop_name': 'Carroll St',
#   'stop_lat': 40.680303,
#   'stop_lon': -73.995048},
#  'F21N': {'stop_name': 'Carroll St',
#   'stop_lat': 40.680303,
#   'stop_lon': -73.995048},
#  'F21S': {'stop_name': 'Carroll St',
#   'stop_lat': 40.680303,
#   'stop_lon': -73.995048},
#  'F22': {'stop_name': 'Smith-9 Sts',
#   'stop_lat': 40.67358,
#   'stop_lon': -73.995959},
#  'F22N': {'stop_name': 'Smith-9 Sts',
#   'stop_lat': 40.67358,
#   'stop_lon': -73.995959},
#  'F22S': {'stop_name': 'Smith-9 Sts',
#   'stop_lat': 40.67358,
#   'stop_lon': -73.995959},
#  'F23': {'stop_name': '4 Av-9 St',
#   'stop_lat': 40.670272,
#   'stop_lon': -73.989779},
#  'F23N': {'stop_name': '4 Av-9 St',
#   'stop_lat': 40.670272,
#   'stop_lon': -73.989779},
#  'F23S': {'stop_name': '4 Av-9 St',
#   'stop_lat': 40.670272,
#   'stop_lon': -73.989779},
#  'F24': {'stop_name': '7 Av', 'stop_lat': 40.666271, 'stop_lon': -73.980305},
#  'F24N': {'stop_name': '7 Av', 'stop_lat': 40.666271, 'stop_lon': -73.980305},
#  'F24S': {'stop_name': '7 Av', 'stop_lat': 40.666271, 'stop_lon': -73.980305},
#  'F25': {'stop_name': '15 St-Prospect Park',
#   'stop_lat': 40.660365,
#   'stop_lon': -73.979493},
#  'F25N': {'stop_name': '15 St-Prospect Park',
#   'stop_lat': 40.660365,
#   'stop_lon': -73.979493},
#  'F25S': {'stop_name': '15 St-Prospect Park',
#   'stop_lat': 40.660365,
#   'stop_lon': -73.979493},
#  'F26': {'stop_name': 'Fort Hamilton Pkwy',
#   'stop_lat': 40.650782,
#   'stop_lon': -73.975776},
#  'F26N': {'stop_name': 'Fort Hamilton Pkwy',
#   'stop_lat': 40.650782,
#   'stop_lon': -73.975776},
#  'F26S': {'stop_name': 'Fort Hamilton Pkwy',
#   'stop_lat': 40.650782,
#   'stop_lon': -73.975776},
#  'F27': {'stop_name': 'Church Av',
#   'stop_lat': 40.644041,
#   'stop_lon': -73.979678},
#  'F27N': {'stop_name': 'Church Av',
#   'stop_lat': 40.644041,
#   'stop_lon': -73.979678},
#  'F27S': {'stop_name': 'Church Av',
#   'stop_lat': 40.644041,
#   'stop_lon': -73.979678},
#  'F29': {'stop_name': 'Ditmas Av',
#   'stop_lat': 40.636119,
#   'stop_lon': -73.978172},
#  'F29N': {'stop_name': 'Ditmas Av',
#   'stop_lat': 40.636119,
#   'stop_lon': -73.978172},
#  'F29S': {'stop_name': 'Ditmas Av',
#   'stop_lat': 40.636119,
#   'stop_lon': -73.978172},
#  'F30': {'stop_name': '18 Av', 'stop_lat': 40.629755, 'stop_lon': -73.976971},
#  'F30N': {'stop_name': '18 Av', 'stop_lat': 40.629755, 'stop_lon': -73.976971},
#  'F30S': {'stop_name': '18 Av', 'stop_lat': 40.629755, 'stop_lon': -73.976971},
#  'F31': {'stop_name': 'Avenue I',
#   'stop_lat': 40.625322,
#   'stop_lon': -73.976127},
#  'F31N': {'stop_name': 'Avenue I',
#   'stop_lat': 40.625322,
#   'stop_lon': -73.976127},
#  'F31S': {'stop_name': 'Avenue I',
#   'stop_lat': 40.625322,
#   'stop_lon': -73.976127},
#  'F32': {'stop_name': 'Bay Pkwy',
#   'stop_lat': 40.620769,
#   'stop_lon': -73.975264},
#  'F32N': {'stop_name': 'Bay Pkwy',
#   'stop_lat': 40.620769,
#   'stop_lon': -73.975264},
#  'F32S': {'stop_name': 'Bay Pkwy',
#   'stop_lat': 40.620769,
#   'stop_lon': -73.975264},
#  'F33': {'stop_name': 'Avenue N',
#   'stop_lat': 40.61514,
#   'stop_lon': -73.974197},
#  'F33N': {'stop_name': 'Avenue N',
#   'stop_lat': 40.61514,
#   'stop_lon': -73.974197},
#  'F33S': {'stop_name': 'Avenue N',
#   'stop_lat': 40.61514,
#   'stop_lon': -73.974197},
#  'F34': {'stop_name': 'Avenue P',
#   'stop_lat': 40.608944,
#   'stop_lon': -73.973022},
#  'F34N': {'stop_name': 'Avenue P',
#   'stop_lat': 40.608944,
#   'stop_lon': -73.973022},
#  'F34S': {'stop_name': 'Avenue P',
#   'stop_lat': 40.608944,
#   'stop_lon': -73.973022},
#  'F35': {'stop_name': 'Kings Hwy',
#   'stop_lat': 40.603217,
#   'stop_lon': -73.972361},
#  'F35N': {'stop_name': 'Kings Hwy',
#   'stop_lat': 40.603217,
#   'stop_lon': -73.972361},
#  'F35S': {'stop_name': 'Kings Hwy',
#   'stop_lat': 40.603217,
#   'stop_lon': -73.972361},
#  'F36': {'stop_name': 'Avenue U',
#   'stop_lat': 40.596063,
#   'stop_lon': -73.973357},
#  'F36N': {'stop_name': 'Avenue U',
#   'stop_lat': 40.596063,
#   'stop_lon': -73.973357},
#  'F36S': {'stop_name': 'Avenue U',
#   'stop_lat': 40.596063,
#   'stop_lon': -73.973357},
#  'F38': {'stop_name': 'Avenue X', 'stop_lat': 40.58962, 'stop_lon': -73.97425},
#  'F38N': {'stop_name': 'Avenue X',
#   'stop_lat': 40.58962,
#   'stop_lon': -73.97425},
#  'F38S': {'stop_name': 'Avenue X',
#   'stop_lat': 40.58962,
#   'stop_lon': -73.97425},
#  'F39': {'stop_name': 'Neptune Av',
#   'stop_lat': 40.581011,
#   'stop_lon': -73.974574},
#  'F39N': {'stop_name': 'Neptune Av',
#   'stop_lat': 40.581011,
#   'stop_lon': -73.974574},
#  'F39S': {'stop_name': 'Neptune Av',
#   'stop_lat': 40.581011,
#   'stop_lon': -73.974574},
#  'G05': {'stop_name': 'Jamaica Center-Parsons/Archer',
#   'stop_lat': 40.702147,
#   'stop_lon': -73.801109},
#  'G05N': {'stop_name': 'Jamaica Center-Parsons/Archer',
#   'stop_lat': 40.702147,
#   'stop_lon': -73.801109},
#  'G05S': {'stop_name': 'Jamaica Center-Parsons/Archer',
#   'stop_lat': 40.702147,
#   'stop_lon': -73.801109},
#  'G06': {'stop_name': 'Sutphin Blvd-Archer Av-JFK Airport',
#   'stop_lat': 40.700486,
#   'stop_lon': -73.807969},
#  'G06N': {'stop_name': 'Sutphin Blvd-Archer Av-JFK Airport',
#   'stop_lat': 40.700486,
#   'stop_lon': -73.807969},
#  'G06S': {'stop_name': 'Sutphin Blvd-Archer Av-JFK Airport',
#   'stop_lat': 40.700486,
#   'stop_lon': -73.807969},
#  'G07': {'stop_name': 'Jamaica-Van Wyck',
#   'stop_lat': 40.702566,
#   'stop_lon': -73.816859},
#  'G07N': {'stop_name': 'Jamaica-Van Wyck',
#   'stop_lat': 40.702566,
#   'stop_lon': -73.816859},
#  'G07S': {'stop_name': 'Jamaica-Van Wyck',
#   'stop_lat': 40.702566,
#   'stop_lon': -73.816859},
#  'G08': {'stop_name': 'Forest Hills-71 Av',
#   'stop_lat': 40.721691,
#   'stop_lon': -73.844521},
#  'G08N': {'stop_name': 'Forest Hills-71 Av',
#   'stop_lat': 40.721691,
#   'stop_lon': -73.844521},
#  'G08S': {'stop_name': 'Forest Hills-71 Av',
#   'stop_lat': 40.721691,
#   'stop_lon': -73.844521},
#  'G09': {'stop_name': '67 Av', 'stop_lat': 40.726523, 'stop_lon': -73.852719},
#  'G09N': {'stop_name': '67 Av', 'stop_lat': 40.726523, 'stop_lon': -73.852719},
#  'G09S': {'stop_name': '67 Av', 'stop_lat': 40.726523, 'stop_lon': -73.852719},
#  'G10': {'stop_name': '63 Dr-Rego Park',
#   'stop_lat': 40.729846,
#   'stop_lon': -73.861604},
#  'G10N': {'stop_name': '63 Dr-Rego Park',
#   'stop_lat': 40.729846,
#   'stop_lon': -73.861604},
#  'G10S': {'stop_name': '63 Dr-Rego Park',
#   'stop_lat': 40.729846,
#   'stop_lon': -73.861604},
#  'G11': {'stop_name': 'Woodhaven Blvd',
#   'stop_lat': 40.733106,
#   'stop_lon': -73.869229},
#  'G11N': {'stop_name': 'Woodhaven Blvd',
#   'stop_lat': 40.733106,
#   'stop_lon': -73.869229},
#  'G11S': {'stop_name': 'Woodhaven Blvd',
#   'stop_lat': 40.733106,
#   'stop_lon': -73.869229},
#  'G12': {'stop_name': 'Grand Av-Newtown',
#   'stop_lat': 40.737015,
#   'stop_lon': -73.877223},
#  'G12N': {'stop_name': 'Grand Av-Newtown',
#   'stop_lat': 40.737015,
#   'stop_lon': -73.877223},
#  'G12S': {'stop_name': 'Grand Av-Newtown',
#   'stop_lat': 40.737015,
#   'stop_lon': -73.877223},
#  'G13': {'stop_name': 'Elmhurst Av',
#   'stop_lat': 40.742454,
#   'stop_lon': -73.882017},
#  'G13N': {'stop_name': 'Elmhurst Av',
#   'stop_lat': 40.742454,
#   'stop_lon': -73.882017},
#  'G13S': {'stop_name': 'Elmhurst Av',
#   'stop_lat': 40.742454,
#   'stop_lon': -73.882017},
#  'G14': {'stop_name': 'Jackson Hts-Roosevelt Av',
#   'stop_lat': 40.746644,
#   'stop_lon': -73.891338},
#  'G14N': {'stop_name': 'Jackson Hts-Roosevelt Av',
#   'stop_lat': 40.746644,
#   'stop_lon': -73.891338},
#  'G14S': {'stop_name': 'Jackson Hts-Roosevelt Av',
#   'stop_lat': 40.746644,
#   'stop_lon': -73.891338},
#  'G15': {'stop_name': '65 St', 'stop_lat': 40.749669, 'stop_lon': -73.898453},
#  'G15N': {'stop_name': '65 St', 'stop_lat': 40.749669, 'stop_lon': -73.898453},
#  'G15S': {'stop_name': '65 St', 'stop_lat': 40.749669, 'stop_lon': -73.898453},
#  'G16': {'stop_name': 'Northern Blvd',
#   'stop_lat': 40.752885,
#   'stop_lon': -73.906006},
#  'G16N': {'stop_name': 'Northern Blvd',
#   'stop_lat': 40.752885,
#   'stop_lon': -73.906006},
#  'G16S': {'stop_name': 'Northern Blvd',
#   'stop_lat': 40.752885,
#   'stop_lon': -73.906006},
#  'G18': {'stop_name': '46 St', 'stop_lat': 40.756312, 'stop_lon': -73.913333},
#  'G18N': {'stop_name': '46 St', 'stop_lat': 40.756312, 'stop_lon': -73.913333},
#  'G18S': {'stop_name': '46 St', 'stop_lat': 40.756312, 'stop_lon': -73.913333},
#  'G19': {'stop_name': 'Steinway St',
#   'stop_lat': 40.756879,
#   'stop_lon': -73.92074},
#  ...}

# %%
for entity in decoded_data.entity:
    if entity.HasField('trip_update'):
        for stu in entity.trip_update.stop_time_update:
            stop_id = stu.stop_id
            stop_info = stop_dict.get(stop_id, {"stop_name": "Unknown Stop", "stop_lat": None, "stop_lon": None})
            
            # Make sure to convert None to a default value or handle it appropriately
            stop_name = stop_info["stop_name"]
            stop_lat = stop_info["stop_lat"] if stop_info["stop_lat"] is not None else "No Latitude"
            stop_lon = stop_info["stop_lon"] if stop_info["stop_lon"] is not None else "No Longitude"
            arrival_time = getattr(stu.arrival, 'time', "No Arrival Time")
            departure_time = getattr(stu.departure, 'time', "No Departure Time")

            print(f"Stop ID: {stop_id}, Stop Name: {stop_name}, Stop Lat: {stop_lat}, Stop Lon: {stop_lon}, Arrival Time: {arrival_time}, Departure Time: {departure_time}")
# Out:
# Stop ID: A19N, Stop Name: 96 St, Stop Lat: 40.791642, Stop Lon: -73.964696, Arrival Time: 1714179479, Departure Time: 1714179479
# Stop ID: A18N, Stop Name: 103 St, Stop Lat: 40.796092, Stop Lon: -73.961454, Arrival Time: 1714179545, Departure Time: 1714179545
# Stop ID: A17N, Stop Name: Cathedral Pkwy (110 St), Stop Lat: 40.800603, Stop Lon: -73.958161, Arrival Time: 1714179605, Departure Time: 1714179605
# Stop ID: A16N, Stop Name: 116 St, Stop Lat: 40.805085, Stop Lon: -73.954882, Arrival Time: 1714179695, Departure Time: 1714179695
# Stop ID: A15N, Stop Name: 125 St, Stop Lat: 40.811109, Stop Lon: -73.952343, Arrival Time: 1714179785, Departure Time: 1714179785
# Stop ID: M18N, Stop Name: Delancey St-Essex St, Stop Lat: 40.718315, Stop Lon: -73.987437, Arrival Time: 1714184700, Departure Time: 1714184700

# %%
import math
import numpy as np

def find_closest_station_miles(lat, lon, stops):
    # Copy the DataFrame to avoid altering original data
    stops_this_click = stops.copy()

    # Calculate the Manhattan distance in miles
    # Adjust calculations to use numpy for vectorized operations
    avg_latitude = (stops_this_click['stop_lat'] + lat) / 2
    miles_per_degree_lon = 69 * np.cos(np.radians(avg_latitude))
    stops_this_click['distance'] = (abs(stops_this_click['stop_lat'] - lat) * 69) + (abs(stops_this_click['stop_lon'] - lon) * miles_per_degree_lon)
    
    # Find the station with the smallest distance
    closest_station = stops_this_click.loc[stops_this_click['distance'].idxmin()]
    
    return closest_station['stop_name'], closest_station['distance']

# %%
import json

def find_closest_station(lat, lon):
    # Calculate Manhattan distance to each station
    stops_this_click = stops.copy()
    stops_this_click['distance'] = abs(stops_this_click['stop_lat'] - lat) + abs(stops_this_click['stop_lon'] - lon)
    
    # Find the station with the smallest distance
    closest_station = stops_this_click.loc[stops_this_click['distance'].idxmin()]
    
    return closest_station['stop_name'], closest_station['distance']

def get_latest_click():
    try:
        with open('clicks.json', 'r') as f:
            data = json.load(f)
        return data['lat'], data['lng']
    except FileNotFoundError:
        print("No clicks recorded yet.")
        return None, None  # or default coordinates

# Usage within your distance calculation function
clicked_lat, clicked_lon = get_latest_click()
if clicked_lat and clicked_lon:
    closest_station_name, closest_distance = find_closest_station(clicked_lat, clicked_lon)
    print(f"The closest station is {closest_station_name} with a Manhattan distance of {closest_distance}")
    closest_station_name_miles, closest_distance_miles = find_closest_station_miles(clicked_lat, clicked_lon, stops)
    print(f"The closest station is {closest_station_name_miles} with a Manhattan distance of {closest_distance_miles:.3f} miles")
    human_walk = closest_distance_miles * 20
    usain_run = closest_distance_miles* 2.15827338129
    print(f"It will take you {human_walk:.0f} minutes to walk to {closest_station_name_miles}")
    print(f"If you were Usain Bolt, you count run there in {usain_run:.2f} minutes")
else:
    print("No valid click coordinates available.")
# Out:
# The closest station is 90 St-Elmhurst Av with a Manhattan distance of 0.003861029653066339
# The closest station is 90 St-Elmhurst Av with a Manhattan distance of 0.248 miles
# It will take you 5 minutes to walk to 90 St-Elmhurst Av
# If you were Usain Bolt, you count run there in 0.53 minutes

# %%
def find_closest_station(lat, lon):
    # Calculate Manhattan distance to each station
    stops_this_click = stops.copy()
    stops_this_click['distance'] = abs(stops_this_click['stop_lat'] - lat) + abs(stops_this_click['stop_lon'] - lon)
    
    # Find the station with the smallest distance
    closest_station = stops_this_click.loc[stops_this_click['distance'].idxmin()]
    
    return closest_station['stop_name'], closest_station['distance']

# Example usage: Simulating a click at a specific location
clicked_lat = 40
clicked_lon = -73
closest_station_name, closest_distance = find_closest_station(clicked_lat, clicked_lon)
print(f"The closest station is {closest_station_name} with a Manhattan distance of {closest_distance}")
# Out:
# The closest station is Far Rockaway-Mott Av with a Manhattan distance of 1.3593999999999937
